# %% [markdown]
# # Spider-Only Adapter Training Notebook
#
# This notebook is scoped to Spider baseline + training only.
# 1. Baseline execution evaluation on Spider
# 2. Fine-tune a Spider adapter
# 3. Compare baseline vs Spider adapter

# %% [markdown]
# ## 1) Install Dependencies (Colab)
#
# Run this once per fresh runtime.

# %%
# !pip -q install --upgrade pip
# !pip -q install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip -q install transformers datasets accelerate bitsandbytes peft trl sentencepiece pandas

# %%
import os
import shutil
import subprocess
import time
from pathlib import Path

REPO_URL = "https://github.com/Arul-7781/QueryMate.git"
REPO_BRANCH = "validation"
FALLBACK_BRANCH = "main"
REPO_DIR = Path('/content/QueryMate')


def run_cmd(cmd, check=True):
    print('$', ' '.join(cmd))
    res = subprocess.run(cmd, text=True, capture_output=True)
    if res.stdout.strip():
        print(res.stdout.strip())
    if res.returncode != 0:
        if res.stderr.strip():
            print(res.stderr.strip())
        if check:
            raise RuntimeError(f"Command failed ({res.returncode}): {' '.join(cmd)}")
    return res


token = os.getenv('GITHUB_TOKEN', '').strip()
auth_url = REPO_URL.replace('https://', f'https://{token}@') if token else REPO_URL


def branch_exists(url, branch):
    res = subprocess.run(['git', 'ls-remote', '--heads', url, branch], text=True, capture_output=True)
    return res.returncode == 0 and bool(res.stdout.strip())


target_branch = REPO_BRANCH if branch_exists(auth_url, REPO_BRANCH) else FALLBACK_BRANCH
if target_branch != REPO_BRANCH:
    print(f"Warning: branch '{REPO_BRANCH}' not found. Falling back to '{FALLBACK_BRANCH}'.")

if REPO_DIR.exists() and not (REPO_DIR / '.git').exists():
    print(f"Removing stale directory: {REPO_DIR}")
    shutil.rmtree(REPO_DIR)

if not REPO_DIR.exists():
    clone_cmd = ['git', 'clone', '--branch', target_branch, '--single-branch', auth_url, str(REPO_DIR)]
    last_error = None
    for attempt in range(1, 4):
        print(f"Clone attempt {attempt}/3")
        res = subprocess.run(clone_cmd, text=True, capture_output=True)
        if res.returncode == 0:
            if res.stdout.strip():
                print(res.stdout.strip())
            break
        last_error = res.stderr.strip() or res.stdout.strip()
        print(last_error)
        time.sleep(2 * attempt)
    else:
        raise RuntimeError(f"Clone failed after 3 attempts. Last error: {last_error}")
else:
    run_cmd(['git', '-C', str(REPO_DIR), 'fetch', 'origin', target_branch], check=False)
    run_cmd(['git', '-C', str(REPO_DIR), 'checkout', target_branch])
    run_cmd(['git', '-C', str(REPO_DIR), 'pull', 'origin', target_branch], check=False)

os.chdir(REPO_DIR)
print('Working directory:', os.getcwd())
print('Top-level files:', sorted(os.listdir('.'))[:20])
# Out:
# $ git -C /content/QueryMate fetch origin validation
# $ git -C /content/QueryMate checkout validation
# Your branch is up to date with 'origin/validation'.
# $ git -C /content/QueryMate pull origin validation
# Already up to date.
# Working directory: /content/QueryMate
# Top-level files: ['.DS_Store', '.git', '.gitignore', 'README.md', 'app.py', 'data', 'docs', 'fetch_papers.py', 'notebooks', 'requirements.txt', 'scripts', 'src', 'tests']

# %% [markdown]
# ## 1.5) Clone QueryMate Repo (Same as First Notebook)
#
# Set `REPO_URL` and branch. This keeps Colab behavior consistent with your original qwen notebook flow.

# %% [markdown]
# ## 2) Setup Imports, Seeds, and Config

# %%
import gc
import os
import re
import sys
import json
import math
import time
import random
import sqlite3
import inspect
import importlib.util
from pathlib import Path
from dataclasses import dataclass
from collections import Counter, defaultdict

import torch
import pandas as pd
from datasets import Dataset, load_dataset
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    BitsAndBytesConfig,
    DataCollatorForLanguageModeling,
    TrainingArguments,
    Trainer,
)
from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training, PeftModel

SEED = 42
random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

BASE_MODEL_ID = "Qwen/Qwen2.5-Coder-3B-Instruct"

# Prefer cloned repo path when available.
if "REPO_DIR" in globals() and Path(REPO_DIR).exists():
    REPO_ROOT = Path(REPO_DIR)
else:
    REPO_ROOT = Path("/content/QueryMate") if Path("/content/QueryMate").exists() else Path.cwd()

if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

TESTS_DIR = REPO_ROOT / "tests"
DATA_DIR = REPO_ROOT / "data"
OUTPUT_ROOT = Path("/content/outputs/dual_adapters")
OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

COMPANY_GOLDEN_PATH = TESTS_DIR / "golden_set1.json"
COMPANY_DB_PATH = DATA_DIR / "company_expanded.db"
if not COMPANY_DB_PATH.exists():
    COMPANY_DB_PATH = DATA_DIR / "company.db"

# Dataset size knobs for faster or fuller runs.
COMPANY_MAX_TRAIN = None
COMPANY_MAX_VAL = 150
COMPANY_MAX_TEST = 50
SPIDER_MAX_TRAIN = 2500
SPIDER_MAX_VAL = 200
SPIDER_MAX_TEST = 50

BASELINE_EVAL_COMPANY_N = 50
BASELINE_EVAL_SPIDER_N = 50
FT_EVAL_COMPANY_N = 50
FT_EVAL_SPIDER_N = 50

MAX_SEQ_LEN = 1024
MAX_NEW_TOKENS = 128

print("Repo root:", REPO_ROOT)
print("Company golden:", COMPANY_GOLDEN_PATH)
print("Company DB:", COMPANY_DB_PATH)
print("Output root:", OUTPUT_ROOT)
print("CUDA available:", torch.cuda.is_available())
# Out:
# Repo root: /content/QueryMate
# Company golden: /content/QueryMate/tests/golden_set1.json
# Company DB: /content/QueryMate/data/company_expanded.db
# Output root: /content/outputs/dual_adapters
# CUDA available: True

# %%
# Override for Spider eval quality: avoid truncated SQL generations.
MAX_NEW_TOKENS = 256
print("MAX_NEW_TOKENS override:", MAX_NEW_TOKENS)
# Out:
# MAX_NEW_TOKENS override: 256

# %% [markdown]
# ## 4) Load Local Spider Dataset and Create a Manageable Subset

# %%
import zipfile


def _is_spider_data_root(root: Path) -> bool:
    if not root.exists() or not root.is_dir():
        return False
    train_ok = (root / "train_spider.json").exists() or (root / "train.json").exists()
    dev_ok = (root / "dev.json").exists() or (root / "validation.json").exists()
    tables_ok = (root / "tables.json").exists()
    return train_ok and dev_ok and tables_ok


def _find_spider_data_root(search_roots):
    for root in search_roots:
        if root is None:
            continue
        root = Path(root)
        if _is_spider_data_root(root):
            return root
        if root.exists() and root.is_dir():
            # Handle nested zip layouts like /content/spider_data/spider_data/*
            for p in root.rglob("tables.json"):
                candidate = p.parent
                if _is_spider_data_root(candidate):
                    return candidate
    return None


def _extract_spider_zip(zip_path: Path, extract_parent: Path) -> Path | None:
    if not zip_path.exists():
        return None
    if not zipfile.is_zipfile(zip_path):
        print(f"Found zip candidate but it is not a valid zip: {zip_path}")
        return None

    extract_parent.mkdir(parents=True, exist_ok=True)
    print(f"Extracting Spider zip: {zip_path} -> {extract_parent}")
    with zipfile.ZipFile(zip_path, "r") as zf:
        zf.extractall(extract_parent)

    found = _find_spider_data_root([
        extract_parent / "spider_data",
        extract_parent,
    ])
    if found is not None:
        print("Detected local Spider data root after extraction:", found)
    return found


def _resolve_spider_local_data_root() -> Path | None:
    override = globals().get("SPIDER_LOCAL_DATA_ROOT_OVERRIDE")

    dir_candidates = [
        REPO_ROOT / "spider_data",
        Path.cwd() / "spider_data",
        Path("/content/spider_data"),
        Path("/content/drive/MyDrive/spider_data"),
        Path("/content/drive/MyDrive/datasets/spider_data"),
    ]

    zip_candidates = [
        REPO_ROOT / "spider_data.zip",
        Path.cwd() / "spider_data.zip",
        Path("/content/spider_data.zip"),
        Path("/content/drive/MyDrive/spider_data.zip"),
        Path("/content/drive/MyDrive/datasets/spider_data.zip"),
    ]

    # Optional override can be either a directory or a zip file.
    if override:
        override_path = Path(override)
        if override_path.suffix.lower() == ".zip":
            extracted = _extract_spider_zip(override_path, Path("/content"))
            if extracted is not None:
                return extracted
        elif _is_spider_data_root(override_path):
            return override_path

    # First try already-existing local folders.
    found = _find_spider_data_root(dir_candidates)
    if found is not None:
        return found

    # Then try extracting known zip locations (Colab upload flow).
    for zip_path in zip_candidates:
        extracted = _extract_spider_zip(zip_path, Path("/content"))
        if extracted is not None:
            return extracted

    return None


def _load_first_json(root: Path, names, label: str):
    for name in names:
        path = root / name
        if path.exists():
            with open(path, "r", encoding="utf-8") as f:
                return json.load(f), path
    raise FileNotFoundError(f"Missing {label}. Tried: {', '.join(names)} under {root}")


SPIDER_LOCAL_ONLY = True
SPIDER_LOCAL_DATA_ROOT = _resolve_spider_local_data_root()
if SPIDER_LOCAL_DATA_ROOT is None:
    raise FileNotFoundError(
        "Could not find local Spider dataset folder or spider_data.zip. "
        "Upload spider_data.zip to /content (or set SPIDER_LOCAL_DATA_ROOT_OVERRIDE)."
    )

spider_train_full, spider_train_path = _load_first_json(
    SPIDER_LOCAL_DATA_ROOT,
    ["train_spider.json", "train.json"],
    "Spider training file",
)
spider_val_full, spider_val_path = _load_first_json(
    SPIDER_LOCAL_DATA_ROOT,
    ["dev.json", "validation.json"],
    "Spider dev file",
)
spider_tables, spider_tables_path = _load_first_json(
    SPIDER_LOCAL_DATA_ROOT,
    ["tables.json"],
    "Spider tables metadata",
)

schema_keys = [
    "table_names",
    "table_names_original",
    "column_names",
    "column_names_original",
    "column_types",
    "primary_keys",
    "foreign_keys",
]
schema_by_db = {row.get("db_id", ""): row for row in spider_tables if isinstance(row, dict)}


def _attach_schema(ex: dict) -> dict:
    out = dict(ex)
    db_id = out.get("db_id", "")
    schema = schema_by_db.get(db_id, {})
    for key in schema_keys:
        if key in schema:
            out[key] = schema[key]
    return out


spider_train_full = [_attach_schema(ex) for ex in spider_train_full if isinstance(ex, dict)]
spider_val_full = [_attach_schema(ex) for ex in spider_val_full if isinstance(ex, dict)]

random.shuffle(spider_train_full)
random.shuffle(spider_val_full)

spider_train = spider_train_full[:SPIDER_MAX_TRAIN] if SPIDER_MAX_TRAIN else spider_train_full

val_cap = SPIDER_MAX_VAL if SPIDER_MAX_VAL else len(spider_val_full)
test_cap = SPIDER_MAX_TEST if SPIDER_MAX_TEST else max(len(spider_val_full) - val_cap, 0)

# Keep validation and test disjoint by taking consecutive slices from local dev split.
spider_val = spider_val_full[:val_cap]
spider_test = spider_val_full[val_cap: val_cap + test_cap]

print("Spider local root:", SPIDER_LOCAL_DATA_ROOT)
print("Spider sources:", {
    "train": str(spider_train_path),
    "dev": str(spider_val_path),
    "tables": str(spider_tables_path),
})
print("Spider split sizes:", {"train": len(spider_train), "val": len(spider_val), "test": len(spider_test)})
print("Spider sample keys:", sorted(list(spider_train[0].keys())) if spider_train else "(empty)")
# Out:
# Spider local root: /content/spider_data
# Spider sources: {'train': '/content/spider_data/train_spider.json', 'dev': '/content/spider_data/dev.json', 'tables': '/content/spider_data/tables.json'}
# Spider split sizes: {'train': 2500, 'val': 200, 'test': 50}
# Spider sample keys: ['column_names', 'column_names_original', 'column_types', 'db_id', 'foreign_keys', 'primary_keys', 'query', 'query_toks', 'query_toks_no_value', 'question', 'question_toks', 'sql', 'table_names', 'table_names_original']

# %%
# Dataset integrity checks for Spider splits.
def _spider_key(ex):
    return (ex.get("db_id", ""), ex.get("question", "").strip().lower())

train_keys = {_spider_key(x) for x in spider_train}
val_keys = {_spider_key(x) for x in spider_val}
test_keys = {_spider_key(x) for x in spider_test}

train_val_overlap = len(train_keys & val_keys)
train_test_overlap = len(train_keys & test_keys)
val_test_overlap = len(val_keys & test_keys)

print("Spider raw split sizes:", {
    "train_full": len(spider_train_full),
    "val_full": len(spider_val_full),
})
print("Spider capped split sizes:", {
    "train": len(spider_train),
    "val": len(spider_val),
    "test": len(spider_test),
})
print("Split overlaps (db_id + normalized question):", {
    "train_val": train_val_overlap,
    "train_test": train_test_overlap,
    "val_test": val_test_overlap,
})
print("Distinct DB IDs in splits:", {
    "train": len({x.get('db_id', '') for x in spider_train}),
    "val": len({x.get('db_id', '') for x in spider_val}),
    "test": len({x.get('db_id', '') for x in spider_test}),
})
# Out:
# Spider raw split sizes: {'train_full': 7000, 'val_full': 1034}
# Spider capped split sizes: {'train': 2500, 'val': 200, 'test': 50}
# Split overlaps (db_id + normalized question): {'train_val': 0, 'train_test': 0, 'val_test': 0}
# Distinct DB IDs in splits: {'train': 140, 'val': 20, 'test': 18}

# %% [markdown]
# ## 5) Utility Functions: Schema, Prompting, SQL Parsing, Runtime, and Evaluation

# %%
def load_company_schema_text(db_path: Path) -> str:
    conn = sqlite3.connect(db_path)
    cur = conn.cursor()
    cur.execute("SELECT name, sql FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite_%' ORDER BY name")
    rows = cur.fetchall()
    conn.close()
    return "\n\n".join([f"{name}: {sql}" for name, sql in rows if sql])


COMPANY_SCHEMA_TEXT = load_company_schema_text(COMPANY_DB_PATH)


def canonical_sql(sql: str) -> str:
    if not sql:
        return ""
    s = sql.strip().strip("`")
    s = re.sub(r"\s+", " ", s)
    return s.lower().rstrip(";")


def extract_sql(text: str) -> str:
    if text is None:
        return ""
    t = text.strip()
    t = t.replace("```sql", "```")
    if "```" in t:
        parts = t.split("```")
        if len(parts) >= 2:
            t = parts[1].strip()

    m = re.search(r"(?is)(with|select)\b[\s\S]*", t)
    if m:
        t = m.group(0).strip()

    # keep the first statement
    if ";" in t:
        t = t.split(";")[0].strip() + ";"
    else:
        t = t.strip() + ";"
    return t


def normalise_rows(rows):
    out = []
    for row in rows:
        norm_row = []
        for v in row:
            if isinstance(v, float):
                norm_row.append(round(v, 6))
            else:
                norm_row.append(v)
        out.append(tuple(norm_row))
    return Counter(out)


def execute_sql(db_path: Path, sql: str):
    try:
        conn = sqlite3.connect(db_path)
        cur = conn.cursor()
        cur.execute(sql)
        rows = cur.fetchall()
        conn.close()
        return rows, None
    except Exception as e:
        return None, str(e)


def spider_schema_text(ex: dict) -> str:
    db_id = ex.get("db_id", "unknown_db")
    tnames = ex.get("table_names_original") or ex.get("table_names") or []
    cnames = ex.get("column_names_original") or ex.get("column_names") or []

    table_to_cols = defaultdict(list)
    for col in cnames:
        if not isinstance(col, (list, tuple)) or len(col) < 2:
            continue
        tidx, cname = col[0], col[1]
        if isinstance(tidx, int) and tidx >= 0 and tidx < len(tnames):
            table_to_cols[tnames[tidx]].append(cname)

    lines = [f"DB: {db_id}"]
    for t in tnames:
        cols = table_to_cols.get(t, [])
        lines.append(f"{t}({', '.join(cols)})")
    return "\n".join(lines)


def company_prompt(question: str) -> str:
    return (
        "You are an expert SQLite SQL assistant. "
        "Generate only SQL with no explanation.\n\n"
        f"Question: {question}\n\n"
        f"Schema:\n{COMPANY_SCHEMA_TEXT}\n\n"
        "SQL:"
    )


def spider_prompt(ex: dict) -> str:
    q = ex.get("question", "")
    schema_txt = spider_schema_text(ex)
    return (
        "You are an expert SQL assistant for text-to-SQL. "
        "Generate only SQL with no explanation.\n\n"
        f"Question: {q}\n\n"
        f"Schema:\n{schema_txt}\n\n"
        "SQL:"
    )


def clear_cuda():
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()


def load_runtime(model_id=BASE_MODEL_ID, adapter_path=None):
    clear_cuda()

    compute_dtype = torch.bfloat16 if torch.cuda.is_available() and torch.cuda.is_bf16_supported() else torch.float16
    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=True,
    )

    tokenizer = AutoTokenizer.from_pretrained(model_id, trust_remote_code=True)
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token

    model = AutoModelForCausalLM.from_pretrained(
        model_id,
        quantization_config=bnb_config,
        device_map="auto",
        trust_remote_code=True,
    )

    if adapter_path is not None:
        model = PeftModel.from_pretrained(model, adapter_path)

    model.eval()
    return {"model": model, "tokenizer": tokenizer, "model_id": model_id, "adapter_path": adapter_path}


def generate_sql(runtime, prompt: str, temperature: float = 0.0, max_new_tokens: int = MAX_NEW_TOKENS) -> str:
    tokenizer = runtime["tokenizer"]
    model = runtime["model"]

    if hasattr(tokenizer, "apply_chat_template"):
        messages = [
            {"role": "system", "content": "Return only SQL."},
            {"role": "user", "content": prompt},
        ]
        input_text = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    else:
        input_text = prompt

    inputs = tokenizer(input_text, return_tensors="pt")
    device = "cuda" if torch.cuda.is_available() else "cpu"
    inputs = {k: v.to(device) for k, v in inputs.items()}

    with torch.no_grad():
        out = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            do_sample=temperature > 0,
            temperature=max(temperature, 0.01) if temperature > 0 else None,
            top_p=0.95 if temperature > 0 else None,
            pad_token_id=tokenizer.eos_token_id,
            eos_token_id=tokenizer.eos_token_id,
        )

    gen_tokens = out[0][inputs["input_ids"].shape[-1]:]
    text = tokenizer.decode(gen_tokens, skip_special_tokens=True).strip()
    return extract_sql(text)


def evaluate_company_execution(runtime, samples, db_path: Path):
    passed, failed, errors = 0, 0, 0
    details = []

    for s in samples:
        q = s["question"]
        expected_sql = s["sql"]
        pred_sql = generate_sql(runtime, company_prompt(q), temperature=0.0)

        exp_rows, exp_err = execute_sql(db_path, expected_sql)
        pred_rows, pred_err = execute_sql(db_path, pred_sql)

        if exp_err is not None:
            errors += 1
            details.append({"question": q, "status": "gold_error", "pred_sql": pred_sql, "error": exp_err})
            continue

        if pred_err is not None:
            failed += 1
            details.append({"question": q, "status": "pred_error", "pred_sql": pred_sql, "error": pred_err})
            continue

        match = normalise_rows(exp_rows) == normalise_rows(pred_rows)
        if match:
            passed += 1
            status = "pass"
        else:
            failed += 1
            status = "fail"

        details.append({"question": q, "status": status, "pred_sql": pred_sql})

    evaluated = max(1, passed + failed)
    return {
        "total": len(samples),
        "passed": passed,
        "failed": failed,
        "errors": errors,
        "execution_accuracy": passed / evaluated,
        "details": details,
    }


def evaluate_spider_exact(runtime, samples):
    passed, failed = 0, 0
    details = []

    for ex in samples:
        q = ex.get("question", "")
        gold_sql = ex.get("query", "")
        pred_sql = generate_sql(runtime, spider_prompt(ex), temperature=0.0)

        match = canonical_sql(gold_sql) == canonical_sql(pred_sql)
        if match:
            passed += 1
            status = "pass"
        else:
            failed += 1
            status = "fail"

        details.append({
            "db_id": ex.get("db_id", ""),
            "question": q,
            "status": status,
            "gold_sql": gold_sql,
            "pred_sql": pred_sql,
        })

    total = max(1, passed + failed)
    return {
        "total": passed + failed,
        "passed": passed,
        "failed": failed,
        "exact_match": passed / total,
        "details": details,
    }


print("Utility functions loaded.")
# Out:
# Utility functions loaded.

# %%
# Override Spider schema/prompt with PK/FK metadata to improve SQL grounding.
def spider_schema_text(ex: dict) -> str:
    db_id = ex.get("db_id", "unknown_db")
    tnames = ex.get("table_names_original") or ex.get("table_names") or []
    cnames = ex.get("column_names_original") or ex.get("column_names") or []
    primary_keys = ex.get("primary_keys") or []
    foreign_keys = ex.get("foreign_keys") or []

    table_to_cols = defaultdict(list)
    col_refs = {}
    for cidx, col in enumerate(cnames):
        if not isinstance(col, (list, tuple)) or len(col) < 2:
            continue
        tidx, cname = col[0], col[1]
        if isinstance(tidx, int) and 0 <= tidx < len(tnames):
            tname = str(tnames[tidx])
            cname = str(cname)
            table_to_cols[tname].append(cname)
            col_refs[cidx] = f"{tname}.{cname}"

    lines = [f"DB: {db_id}"]
    for t in tnames:
        cols = table_to_cols.get(str(t), [])
        lines.append(f"{t}({', '.join(cols)})")

    pk_cols = [col_refs.get(idx) for idx in primary_keys if idx in col_refs]
    if pk_cols:
        lines.append("Primary Keys: " + ", ".join(pk_cols))

    fk_lines = []
    for pair in foreign_keys:
        if not isinstance(pair, (list, tuple)) or len(pair) < 2:
            continue
        src = col_refs.get(pair[0])
        dst = col_refs.get(pair[1])
        if src and dst:
            fk_lines.append(f"{src} -> {dst}")
    if fk_lines:
        lines.append("Foreign Keys: " + " | ".join(fk_lines))

    return "\n".join(lines)


def spider_prompt(ex: dict) -> str:
    q = ex.get("question", "")
    schema_txt = spider_schema_text(ex)
    return (
        "You are an expert SQLite text-to-SQL assistant. "
        "Return exactly one executable SQLite query and nothing else.\n\n"
        "Rules:\n"
        "1) Use only tables/columns shown in the schema.\n"
        "2) Prefer explicit joins using matching key columns.\n"
        "3) Do not add explanations, markdown, or extra text.\n\n"
        f"Question: {q}\n\n"
        f"Schema:\n{schema_txt}\n\n"
        "SQL:"
    )


print("Spider schema/prompt override loaded (with PK/FK metadata).")
# Out:
# Spider schema/prompt override loaded (with PK/FK metadata).

# %%
# Override with a safer generation helper (avoids passing None generation args).
def generate_sql(runtime, prompt: str, temperature: float = 0.0, max_new_tokens: int = MAX_NEW_TOKENS) -> str:
    tokenizer = runtime["tokenizer"]
    model = runtime["model"]

    if hasattr(tokenizer, "apply_chat_template"):
        messages = [
            {"role": "system", "content": "Return only SQL."},
            {"role": "user", "content": prompt},
        ]
        input_text = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    else:
        input_text = prompt

    inputs = tokenizer(input_text, return_tensors="pt")
    device = "cuda" if torch.cuda.is_available() else "cpu"
    inputs = {k: v.to(device) for k, v in inputs.items()}

    gen_kwargs = {
        "max_new_tokens": max_new_tokens,
        "do_sample": temperature > 0,
        "pad_token_id": tokenizer.eos_token_id,
        "eos_token_id": tokenizer.eos_token_id,
    }
    if temperature > 0:
        gen_kwargs["temperature"] = max(temperature, 0.01)
        gen_kwargs["top_p"] = 0.95

    with torch.no_grad():
        out = model.generate(**inputs, **gen_kwargs)

    gen_tokens = out[0][inputs["input_ids"].shape[-1]:]
    text = tokenizer.decode(gen_tokens, skip_special_tokens=True).strip()
    return extract_sql(text)

print("Generation helper ready.")
# Out:
# Generation helper ready.

# %%
import types


def install_querymate_compat_shims():
    # Provide provider-free shims so repo imports work in local Qwen-only runs.
    if "src.llm_engine" not in sys.modules:
        llm_mod = types.ModuleType("src.llm_engine")

        def _disabled_provider_invoke(prompt, temperature=0.0):
            raise RuntimeError(
                "External provider invoke_with_fallback is disabled in this notebook runtime. "
                "Use patch_agents_with_runtime(...) to route generation through local Qwen runtime."
            )

        llm_mod.invoke_with_fallback = _disabled_provider_invoke
        sys.modules["src.llm_engine"] = llm_mod

    if "src.schema_rag" not in sys.modules:
        rag_mod = types.ModuleType("src.schema_rag")

        def _init_schema_vectorstore_noop():
            return None

        def _retrieve_relevant_schemas_fallback(question, top_k=3):
            schema_txt = globals().get("COMPANY_SCHEMA_TEXT", "")
            if schema_txt:
                return (
                    "Relevant Tables:\n\n"
                    f"{schema_txt}\n\n"
                    "Relationships:\n"
                    "- Employees.DeptID links to Departments.DeptID\n"
                    "- Projects.DeptID links to Departments.DeptID"
                )
            return "Relevant Tables:\n(Company schema unavailable in fallback mode.)"

        rag_mod.initialize_schema_vectorstore = _init_schema_vectorstore_noop
        rag_mod.retrieve_relevant_schemas = _retrieve_relevant_schemas_fallback
        sys.modules["src.schema_rag"] = rag_mod


install_querymate_compat_shims()

# Load evaluator from repo path (avoids import collisions with unrelated `tests` packages).
EVALUATOR_PATH = REPO_ROOT / "tests" / "evaluator.py"
if not EVALUATOR_PATH.exists():
    raise FileNotFoundError(f"Missing evaluator at: {EVALUATOR_PATH}")

spec_eval = importlib.util.spec_from_file_location("querymate_evaluator", EVALUATOR_PATH)
evaluator = importlib.util.module_from_spec(spec_eval)
if spec_eval is None or spec_eval.loader is None:
    raise RuntimeError("Could not load QueryMate evaluator module")
spec_eval.loader.exec_module(evaluator)

evaluator.DB_PATH = str(COMPANY_DB_PATH)
evaluator.GOLDEN_SET = str(COMPANY_GOLDEN_PATH)
evaluator.SLEEP_BETWEEN = 0.0


@dataclass
class LocalResponse:
    content: str


class AgenticRuntime:
    def __init__(self, runtime_dict):
        self.runtime_dict = runtime_dict

    def invoke(self, prompt, temperature=0.0):
        sql = generate_sql(self.runtime_dict, prompt, temperature=temperature)
        return LocalResponse(content=sql)


def patch_agents_with_runtime(runtime_obj):
    import src.agents as agents

    agents._ACTIVE_RUNTIME = runtime_obj

    def local_invoke_with_fallback(prompt, temperature=0.0):
        active_runtime = getattr(agents, "_ACTIVE_RUNTIME", None)
        if active_runtime is None:
            raise RuntimeError("No active runtime patched. Call patch_agents_with_runtime first.")
        return active_runtime.invoke(prompt, temperature=temperature)

    agents.invoke_with_fallback = local_invoke_with_fallback
    return agents


def clear_runtime_patch():
    import src.agents as agents
    if hasattr(agents, "_ACTIVE_RUNTIME"):
        agents._ACTIVE_RUNTIME = None


def evaluate_company_agentic(runtime_dict, samples):
    clear_runtime_patch()
    patch_agents_with_runtime(AgenticRuntime(runtime_dict))
    report = evaluator.run_evaluation(samples)
    clear_runtime_patch()
    return report


print("QueryMate agentic bridge ready (provider-free shim mode).")
# Out:
# 🔧 Initializing RAG Schema Vectorstore...
# ✅ RAG System Ready!
# QueryMate agentic bridge ready (provider-free shim mode).

# %% [markdown]
# ## 5.5) QueryMate Agentic Bridge (Same Evaluation Pattern as First Notebook)
#
# This section patches QueryMate agent runtime invocation and uses `tests/evaluator.py` for company-domain execution accuracy, matching the first notebook's evaluation style.

# %% [markdown]
# ## 5.6) Spider Agentic RAG + Company-Style Execution Evaluator
#
# This section applies the same QueryMate-style agentic workflow to Spider queries by:
# - resolving each Spider database file,
# - retrieving relevant table schema text (RAG-style retrieval per query),
# - running agentic SQL generation,
# - scoring with strict/relaxed/partial execution metrics (same strategy as company evaluator).

# %%
import zipfile
import urllib.request
from urllib.error import HTTPError, URLError
import subprocess


def _looks_like_spider_db_root(path: Path) -> bool:
    if not path.exists() or not path.is_dir():
        return False
    has_sqlite = any(path.glob("*/*.sqlite"))
    has_db = any(path.glob("*/*.db"))
    return has_sqlite or has_db


def _scan_for_spider_db_root(search_roots):
    # Fallback recursive search when extracted folder names vary.
    for root in search_roots:
        if root is None:
            continue
        root = Path(root)
        if not root.exists() or not root.is_dir():
            continue
        for pattern in ("*.sqlite", "*.db"):
            for db_file in root.rglob(pattern):
                for parent in [db_file.parent, *db_file.parents]:
                    if parent.name == "database" and _looks_like_spider_db_root(parent):
                        return parent
    return None


def _find_spider_db_root():
    local_root = globals().get("SPIDER_LOCAL_DATA_ROOT")
    local_candidates = []
    if local_root:
        local_root = Path(local_root)
        local_candidates.extend([
            local_root / "database",
            local_root / "test_database",
        ])

    candidates = local_candidates + [
        REPO_ROOT / "spider_data" / "database",
        REPO_ROOT / "spider_data" / "test_database",
        REPO_ROOT / "data" / "spider" / "database",
        REPO_ROOT / "data" / "spider" / "databases",
        Path.cwd() / "spider_data" / "database",
        Path.cwd() / "spider_data" / "test_database",
        Path("/content/spider/database"),
        Path("/content/spider_data/database"),
        Path("/content/database"),
        Path("/content/spider-master/database"),
        Path("/content/spider-main/database"),
        Path("/content/spider_repo/database"),
        Path("/content/spider_repo/spider/database"),
        Path("/content/spider-master/spider/database"),
        Path("/content/spider-main/spider/database"),
    ]
    for c in candidates:
        if _looks_like_spider_db_root(c):
            return c

    scan_roots = [
        local_root if local_root else None,
        REPO_ROOT,
        REPO_ROOT / "spider_data",
        Path("/content"),
        Path("/content/spider"),
        REPO_ROOT / "data",
        Path.cwd(),
    ]
    return _scan_for_spider_db_root(scan_roots)


def _download_with_status(url: str, dest: Path, min_size_bytes: int = 1024):
    print(f"Trying Spider DB download: {url}")
    try:
        urllib.request.urlretrieve(url, dest)
        if dest.exists() and dest.stat().st_size >= min_size_bytes:
            print(f"Downloaded: {dest} ({dest.stat().st_size} bytes)")
            return True
        print(f"Downloaded file too small, skipping: {dest}")
        return False
    except (HTTPError, URLError) as e:
        print(f"Download failed from {url}: {e}")
        return False
    except Exception as e:
        print(f"Download failed from {url}: {e}")
        return False


def _extract_zip_safe(zip_path: Path, target_dir: Path):
    try:
        if not zipfile.is_zipfile(zip_path):
            print(f"Not a valid zip file: {zip_path}")
            return False
        with zipfile.ZipFile(zip_path, "r") as zf:
            zf.extractall(target_dir)
        print(f"Extracted: {zip_path} -> {target_dir}")
        return True
    except Exception as e:
        print(f"Failed to extract zip {zip_path}: {e}")
        return False


def _download_spider_via_gdown(target_dir: Path):
    # Official Spider data link exposed on the Spider task page.
    drive_file_id = "1403EGqzIDoHMdQF4c9Bkyl7dZLZ5Wt6J"
    out_zip = target_dir / "spider_data.zip"

    try:
        import gdown
    except Exception:
        try:
            print("Installing gdown for Google Drive download...")
            subprocess.check_call([sys.executable, "-m", "pip", "-q", "install", "gdown"])
            import gdown
        except Exception as e:
            print(f"Could not install/import gdown: {e}")
            return None

    url = f"https://drive.google.com/uc?id={drive_file_id}"
    try:
        print(f"Trying Spider DB download via Google Drive file id: {drive_file_id}")
        gdown.download(url=url, output=str(out_zip), quiet=False, fuzzy=True)
        if out_zip.exists() and out_zip.stat().st_size > 1024 * 1024:
            print(f"Downloaded: {out_zip} ({out_zip.stat().st_size} bytes)")
            return out_zip
        print("Google Drive download did not produce a usable archive.")
        return None
    except Exception as e:
        print(f"Google Drive download failed: {e}")
        return None


def _maybe_download_spider_db_root():
    root = _find_spider_db_root()
    if root is not None:
        return root

    # Fully-local mode: fail fast with clear setup guidance.
    if globals().get("SPIDER_LOCAL_ONLY", False):
        raise FileNotFoundError(
            "Could not find Spider database folder in local mode. "
            "Expected <spider_data>/database under SPIDER_LOCAL_DATA_ROOT."
        )

    target_dir = Path("/content/spider")
    target_dir.mkdir(parents=True, exist_ok=True)

    # Old direct database links sometimes 404; keep for compatibility.
    direct_db_urls = [
        "https://raw.githubusercontent.com/taoyds/spider/master/database/database.zip",
        "https://github.com/taoyds/spider/raw/master/database/database.zip",
    ]

    # Fallback 1: full Spider repo archive (no DB in recent snapshots, but cheap to try).
    repo_archive_urls = [
        "https://github.com/taoyds/spider/archive/refs/heads/master.zip",
        "https://github.com/taoyds/spider/archive/refs/heads/main.zip",
        "https://codeload.github.com/taoyds/spider/zip/refs/heads/master",
        "https://codeload.github.com/taoyds/spider/zip/refs/heads/main",
    ]

    db_zip_path = target_dir / "database.zip"
    for url in direct_db_urls:
        if _download_with_status(url, db_zip_path, min_size_bytes=50 * 1024):
            if _extract_zip_safe(db_zip_path, target_dir):
                root = _find_spider_db_root()
                if root is not None:
                    return root

    repo_zip_path = target_dir / "spider_repo.zip"
    for url in repo_archive_urls:
        if _download_with_status(url, repo_zip_path, min_size_bytes=5 * 1024 * 1024):
            if _extract_zip_safe(repo_zip_path, Path("/content")):
                root = _find_spider_db_root()
                if root is not None:
                    return root

    # Fallback 2: official Google Drive dataset package.
    drive_zip = _download_spider_via_gdown(target_dir)
    if drive_zip is not None and _extract_zip_safe(drive_zip, Path("/content")):
        root = _find_spider_db_root()
        if root is not None:
            return root

    return _find_spider_db_root()


SPIDER_DB_ROOT = _maybe_download_spider_db_root()
print("SPIDER_DB_ROOT:", SPIDER_DB_ROOT)


def resolve_spider_db_path(example: dict):
    direct = example.get("db_path")
    if direct:
        p = Path(direct)
        if p.exists():
            return p

    db_id = example.get("db_id")
    if not db_id or SPIDER_DB_ROOT is None:
        return None

    candidates = [
        SPIDER_DB_ROOT / db_id / f"{db_id}.sqlite",
        SPIDER_DB_ROOT / db_id / f"{db_id}.db",
        SPIDER_DB_ROOT / f"{db_id}.sqlite",
    ]

    for p in candidates:
        if p.exists():
            return p
    return None


def _spider_table_docs(ex: dict):
    tnames = ex.get("table_names_original") or ex.get("table_names") or []
    cnames = ex.get("column_names_original") or ex.get("column_names") or []

    table_to_cols = defaultdict(list)
    for col in cnames:
        if not isinstance(col, (list, tuple)) or len(col) < 2:
            continue
        tidx, cname = col[0], col[1]
        if isinstance(tidx, int) and 0 <= tidx < len(tnames):
            table_to_cols[tnames[tidx]].append(str(cname))

    docs = []
    for t in tnames:
        cols = table_to_cols.get(t, [])
        doc = f"Table {t} with columns: {', '.join(cols)}"
        docs.append((t, doc))
    return docs


def retrieve_spider_relevant_schemas(question: str, ex: dict, top_k: int = 4):
    # Lightweight retrieval over table descriptions (RAG-style per database).
    q_tokens = set(re.findall(r"[a-zA-Z0-9_]+", question.lower()))
    scored = []
    for table_name, doc in _spider_table_docs(ex):
        d_tokens = set(re.findall(r"[a-zA-Z0-9_]+", doc.lower()))
        score = len(q_tokens & d_tokens)
        scored.append((score, table_name, doc))

    scored.sort(key=lambda x: (x[0], x[1]), reverse=True)
    selected = scored[:top_k] if scored else []

    schema_lines = [f"DB: {ex.get('db_id', 'unknown_db')}"]
    for _, _, doc in selected:
        schema_lines.append(doc)

    if len(schema_lines) == 1:
        schema_lines.append("No schema metadata found for this sample.")

    return "\n".join(schema_lines)


def execute_sql_on_db(db_path: Path, sql: str):
    try:
        conn = sqlite3.connect(db_path)
        cur = conn.cursor()
        cur.execute(sql)
        rows = cur.fetchall()
        conn.close()
        return rows, None
    except Exception as e:
        return None, str(e)


def evaluate_spider_agentic_execution(runtime_dict, samples, top_k=4):
    import src.agents as agents

    clear_runtime_patch()
    patch_agents_with_runtime(AgenticRuntime(runtime_dict))

    total = len(samples)
    passed = failed = errors = 0
    strict_passed = strict_failed = 0
    projection_subset_passed = 0
    partial_credit_total = 0.0
    details = []

    orig_schema_expert = agents.agent_schema_expert
    orig_db_path = agents.DB_PATH

    for ex in samples:
        question = ex.get("question", "")
        gold_sql = ex.get("query", "")
        db_path = resolve_spider_db_path(ex)

        if db_path is None:
            errors += 1
            details.append({
                "db_id": ex.get("db_id", ""),
                "question": question,
                "strict_outcome": "ERROR",
                "outcome": "ERROR",
                "error": "Missing Spider sqlite DB file for db_id",
            })
            continue

        agents.DB_PATH = str(db_path)

        def _schema_expert_for_spider(q, ex_ref=ex):
            return retrieve_spider_relevant_schemas(q, ex_ref, top_k=top_k)

        agents.agent_schema_expert = _schema_expert_for_spider

        try:
            result = agents.run_query_agentic(question)
            pred_sql = result.get("sql", "")

            exp_rows, exp_err = execute_sql_on_db(db_path, gold_sql)
            pred_rows, pred_err = execute_sql_on_db(db_path, pred_sql)

            if exp_err is not None:
                errors += 1
                details.append({
                    "db_id": ex.get("db_id", ""),
                    "question": question,
                    "strict_outcome": "ERROR",
                    "outcome": "ERROR",
                    "error": f"gold_error: {exp_err}",
                })
                continue

            if pred_err is not None:
                failed += 1
                strict_failed += 1
                details.append({
                    "db_id": ex.get("db_id", ""),
                    "question": question,
                    "strict_outcome": "FAIL",
                    "outcome": "FAIL",
                    "match_type": "none",
                    "partial_credit": 0.0,
                    "pred_sql": pred_sql,
                    "error": pred_err,
                })
                continue

            cls = evaluator.classify_result_match(exp_rows, pred_rows)
            relaxed_ok = cls["relaxed_match"]
            strict_ok = cls["legacy_match"]
            match_type = cls["match_type"]
            partial_credit = cls["partial_credit"]

            if relaxed_ok:
                passed += 1
            else:
                failed += 1

            if strict_ok:
                strict_passed += 1
            else:
                strict_failed += 1

            if match_type == "actual_subset_projection":
                projection_subset_passed += 1

            partial_credit_total += partial_credit

            details.append({
                "db_id": ex.get("db_id", ""),
                "question": question,
                "strict_outcome": "PASS" if strict_ok else "FAIL",
                "outcome": "PASS" if relaxed_ok else "FAIL",
                "match_type": match_type,
                "partial_credit": partial_credit,
                "pred_sql": pred_sql,
            })

        except Exception as e:
            errors += 1
            details.append({
                "db_id": ex.get("db_id", ""),
                "question": question,
                "strict_outcome": "ERROR",
                "outcome": "ERROR",
                "error": str(e),
            })

    # restore
    agents.agent_schema_expert = orig_schema_expert
    agents.DB_PATH = orig_db_path
    clear_runtime_patch()

    evaluated = total - errors
    denom = evaluated if evaluated > 0 else 1

    return {
        "total": total,
        "passed": passed,
        "failed": failed,
        "strict_passed": strict_passed,
        "strict_failed": strict_failed,
        "projection_subset_passed": projection_subset_passed,
        "errors": errors,
        "execution_accuracy": passed / denom,
        "strict_execution_accuracy": strict_passed / denom,
        "partial_credit_accuracy": partial_credit_total / denom,
        "details": details,
    }


print("Spider agentic RAG + execution evaluator ready.")
# Out:
# SPIDER_DB_ROOT: /content/spider_data/database
# Spider agentic RAG + execution evaluator ready.

# %%
# Sanity check: verify Spider DB mapping and gold SQL executability.
check_n = min(50, len(spider_test))
missing_db = 0
gold_exec_errors = 0

for ex in spider_test[:check_n]:
    db_path = resolve_spider_db_path(ex)
    if db_path is None:
        missing_db += 1
        continue

    _, err = execute_sql_on_db(db_path, ex.get("query", ""))
    if err is not None:
        gold_exec_errors += 1

print({
    "checked": check_n,
    "missing_db": missing_db,
    "gold_exec_errors": gold_exec_errors,
})
# Out:
# {'checked': 50, 'missing_db': 0, 'gold_exec_errors': 0}

# %%
# Progress-logging override for spider execution eval so long runs are visible.

def evaluate_spider_agentic_execution(runtime_dict, samples, top_k=4, progress_every=5):

    import src.agents as agents



    clear_runtime_patch()

    patch_agents_with_runtime(AgenticRuntime(runtime_dict))



    total = len(samples)

    passed = failed = errors = 0

    strict_passed = strict_failed = 0

    projection_subset_passed = 0

    partial_credit_total = 0.0

    details = []



    start_ts = time.time()

    print(f"Spider eval started: {total} samples")



    orig_schema_expert = agents.agent_schema_expert

    orig_db_path = agents.DB_PATH



    for idx, ex in enumerate(tqdm(samples, desc="Spider evaluation", unit="query"), start=1):

        question = ex.get("question", "")

        gold_sql = ex.get("query", "")

        db_id = ex.get("db_id", "")



        if idx == 1 or idx % max(1, progress_every) == 0:

            elapsed = time.time() - start_ts

            print(f"[{idx}/{total}] db_id={db_id} elapsed={elapsed:.1f}s")



        db_path = resolve_spider_db_path(ex)



        if db_path is None:

            errors += 1

            details.append({

                "db_id": db_id,

                "question": question,

                "strict_outcome": "ERROR",

                "outcome": "ERROR",

                "error": "Missing Spider sqlite DB file for db_id",

            })

            continue



        agents.DB_PATH = str(db_path)



        def _schema_expert_for_spider(q, ex_ref=ex):

            return retrieve_spider_relevant_schemas(q, ex_ref, top_k=top_k)



        agents.agent_schema_expert = _schema_expert_for_spider



        try:

            result = agents.run_query_agentic(question)

            pred_sql = result.get("sql", "")



            exp_rows, exp_err = execute_sql_on_db(db_path, gold_sql)

            pred_rows, pred_err = execute_sql_on_db(db_path, pred_sql)



            if exp_err is not None:

                errors += 1

                details.append({

                    "db_id": db_id,

                    "question": question,

                    "strict_outcome": "ERROR",

                    "outcome": "ERROR",

                    "error": f"gold_error: {exp_err}",

                })

                continue



            if pred_err is not None:

                failed += 1

                strict_failed += 1

                details.append({

                    "db_id": db_id,

                    "question": question,

                    "strict_outcome": "FAIL",

                    "outcome": "FAIL",

                    "match_type": "none",

                    "partial_credit": 0.0,

                    "pred_sql": pred_sql,

                    "error": pred_err,

                })

                continue



            cls = evaluator.classify_result_match(exp_rows, pred_rows)

            relaxed_ok = cls["relaxed_match"]

            strict_ok = cls["legacy_match"]

            match_type = cls["match_type"]

            partial_credit = cls["partial_credit"]



            if relaxed_ok:

                passed += 1

            else:

                failed += 1



            if strict_ok:

                strict_passed += 1

            else:

                strict_failed += 1



            if match_type == "actual_subset_projection":

                projection_subset_passed += 1



            partial_credit_total += partial_credit



            details.append({

                "db_id": db_id,

                "question": question,

                "strict_outcome": "PASS" if strict_ok else "FAIL",

                "outcome": "PASS" if relaxed_ok else "FAIL",

                "match_type": match_type,

                "partial_credit": partial_credit,

                "pred_sql": pred_sql,

            })



        except Exception as e:

            errors += 1

            details.append({

                "db_id": db_id,

                "question": question,

                "strict_outcome": "ERROR",

                "outcome": "ERROR",

                "error": str(e),

            })



    # restore

    agents.agent_schema_expert = orig_schema_expert

    agents.DB_PATH = orig_db_path

    clear_runtime_patch()



    evaluated = total - errors

    denom = evaluated if evaluated > 0 else 1



    elapsed_total = time.time() - start_ts

    print(

        f"Spider eval done in {elapsed_total:.1f}s | "

        f"relaxed={passed}/{denom} strict={strict_passed}/{denom} errors={errors}"

    )



    return {

        "total": total,

        "passed": passed,

        "failed": failed,

        "strict_passed": strict_passed,

        "strict_failed": strict_failed,

        "projection_subset_passed": projection_subset_passed,

        "errors": errors,

        "execution_accuracy": passed / denom,

        "strict_execution_accuracy": strict_passed / denom,

        "partial_credit_accuracy": partial_credit_total / denom,

        "details": details,

    }



print("Spider evaluator progress override loaded.")
# Out:
# Spider evaluator progress override loaded.

# %%
from tqdm.auto import tqdm
print("tqdm import ready.")
# Out:
# tqdm import ready.

# %%
# Direct Spider execution evaluator with detailed logging for per-query debugging.
def _preview_text(text: str, max_chars: int = 180) -> str:
    text = re.sub(r"\s+", " ", str(text or "")).strip()
    if len(text) <= max_chars:
        return text
    return text[: max_chars - 3] + "..."


def evaluate_spider_direct_execution(
    runtime_dict,
    samples,
    progress_desc="Spider direct execution eval",
    verbose=False,
    log_every=1,
    show_sql_preview=False,
    preview_chars=180,
):
    from tqdm.auto import tqdm

    total = len(samples)
    passed = failed = errors = 0
    strict_passed = strict_failed = 0
    projection_subset_passed = 0
    partial_credit_total = 0.0
    pred_exec_errors = 0
    details = []

    for idx, ex in enumerate(tqdm(samples, desc=progress_desc, unit="query"), start=1):
        question = ex.get("question", "")
        db_id = ex.get("db_id", "")
        gold_sql = ex.get("query", "")
        db_path = resolve_spider_db_path(ex)

        should_log = verbose and (idx == 1 or idx % max(1, log_every) == 0)
        if should_log:
            tqdm.write(
                f"[{idx}/{total}] db_id={db_id} question={_preview_text(question, preview_chars)}"
            )

        if db_path is None:
            errors += 1
            details.append({
                "db_id": db_id,
                "question": question,
                "gold_sql": gold_sql,
                "strict_outcome": "ERROR",
                "outcome": "ERROR",
                "error": "Missing Spider sqlite DB file for db_id",
            })
            if should_log:
                tqdm.write("  -> ERROR: missing DB file")
            continue

        exp_rows, exp_err = execute_sql_on_db(db_path, gold_sql)
        if exp_err is not None:
            errors += 1
            details.append({
                "db_id": db_id,
                "question": question,
                "gold_sql": gold_sql,
                "strict_outcome": "ERROR",
                "outcome": "ERROR",
                "error": f"gold_error: {exp_err}",
            })
            if should_log:
                tqdm.write(f"  -> ERROR: gold SQL failed ({_preview_text(exp_err, 120)})")
            continue

        # First pass generation.
        pred_sql = generate_sql(runtime_dict, spider_prompt(ex), temperature=0.0, max_new_tokens=MAX_NEW_TOKENS)
        pred_rows, pred_err = execute_sql_on_db(db_path, pred_sql)

        # One lightweight repair retry when SQL fails to execute.
        if pred_err is not None:
            repair_prompt = (
                spider_prompt(ex)
                + "\nPrevious SQL failed to execute. Return a corrected SQL query only."
            )
            pred_sql_retry = generate_sql(
                runtime_dict,
                repair_prompt,
                temperature=0.0,
                max_new_tokens=MAX_NEW_TOKENS + 128,
            )
            retry_rows, retry_err = execute_sql_on_db(db_path, pred_sql_retry)
            if retry_err is None:
                pred_sql = pred_sql_retry
                pred_rows = retry_rows
                pred_err = None

        if pred_err is not None:
            pred_exec_errors += 1
            failed += 1
            strict_failed += 1
            details.append({
                "db_id": db_id,
                "question": question,
                "gold_sql": gold_sql,
                "strict_outcome": "FAIL",
                "outcome": "FAIL",
                "match_type": "none",
                "partial_credit": 0.0,
                "pred_sql": pred_sql,
                "error": pred_err,
            })
            if should_log:
                tqdm.write(f"  -> FAIL: predicted SQL execution error ({_preview_text(pred_err, 120)})")
                if show_sql_preview:
                    tqdm.write(f"     gold_sql: {_preview_text(gold_sql, preview_chars)}")
                    tqdm.write(f"     pred_sql: {_preview_text(pred_sql, preview_chars)}")
            continue

        cls = evaluator.classify_result_match(exp_rows, pred_rows)
        relaxed_ok = cls["relaxed_match"]
        strict_ok = cls["legacy_match"]
        match_type = cls["match_type"]
        partial_credit = cls["partial_credit"]

        if relaxed_ok:
            passed += 1
        else:
            failed += 1

        if strict_ok:
            strict_passed += 1
        else:
            strict_failed += 1

        if match_type == "actual_subset_projection":
            projection_subset_passed += 1

        partial_credit_total += partial_credit

        details.append({
            "db_id": db_id,
            "question": question,
            "gold_sql": gold_sql,
            "strict_outcome": "PASS" if strict_ok else "FAIL",
            "outcome": "PASS" if relaxed_ok else "FAIL",
            "match_type": match_type,
            "partial_credit": partial_credit,
            "pred_sql": pred_sql,
        })

        if should_log:
            tqdm.write(
                "  -> "
                + ("PASS" if relaxed_ok else "FAIL")
                + f" | strict={'PASS' if strict_ok else 'FAIL'} | match={match_type} | partial={partial_credit:.2f}"
            )
            if show_sql_preview:
                tqdm.write(f"     gold_sql: {_preview_text(gold_sql, preview_chars)}")
                tqdm.write(f"     pred_sql: {_preview_text(pred_sql, preview_chars)}")

    evaluated = total - errors
    denom = evaluated if evaluated > 0 else 1

    return {
        "total": total,
        "passed": passed,
        "failed": failed,
        "strict_passed": strict_passed,
        "strict_failed": strict_failed,
        "projection_subset_passed": projection_subset_passed,
        "errors": errors,
        "pred_exec_errors": pred_exec_errors,
        "execution_accuracy": passed / denom,
        "strict_execution_accuracy": strict_passed / denom,
        "partial_credit_accuracy": partial_credit_total / denom,
        "details": details,
    }


def print_spider_eval_debug(report: dict, n: int = 10):
    details = report.get("details", [])
    failed_items = [d for d in details if d.get("outcome") != "PASS"]
    print("Spider eval debug summary:", {
        "total": report.get("total"),
        "passed": report.get("passed"),
        "failed": report.get("failed"),
        "errors": report.get("errors"),
        "pred_exec_errors": report.get("pred_exec_errors", 0),
    })
    print(f"Showing first {min(n, len(failed_items))} non-pass examples")

    for i, item in enumerate(failed_items[:n], start=1):
        print("-" * 80)
        print(f"[{i}] db_id={item.get('db_id', '')} outcome={item.get('outcome', '')} strict={item.get('strict_outcome', '')}")
        print(f"Q: {_preview_text(item.get('question', ''), 220)}")
        if item.get("error"):
            print(f"Error: {_preview_text(item.get('error', ''), 220)}")
        if item.get("match_type") is not None:
            print(f"Match type: {item.get('match_type')} | Partial: {item.get('partial_credit')}")
        if item.get("gold_sql") is not None:
            print(f"Gold: {_preview_text(item.get('gold_sql', ''), 300)}")
        if item.get("pred_sql") is not None:
            print(f"Pred: {_preview_text(item.get('pred_sql', ''), 300)}")


print("Spider direct execution evaluator ready (verbose mode + debug dump).")
# Out:
# Spider direct execution evaluator ready (verbose mode + debug dump).

# %%
# Preview exact Spider eval questions/queries before running inference.
def preview_spider_eval_set(samples, n=12):
    n = min(n, len(samples))
    print(f"Previewing {n} Spider eval samples")
    for idx, ex in enumerate(samples[:n], start=1):
        db_id = ex.get("db_id", "")
        question = ex.get("question", "")
        gold_sql = ex.get("query", "")
        db_path = resolve_spider_db_path(ex)

        if db_path is None:
            db_status = "missing_db"
            gold_exec = "n/a"
        else:
            _, err = execute_sql_on_db(db_path, gold_sql)
            db_status = "ok"
            gold_exec = "ok" if err is None else f"gold_error: {err}"

        print(f"[{idx}] db_id={db_id} db={db_status} gold_exec={_preview_text(gold_exec, 120)}")
        print(f"    Q: {_preview_text(question, 220)}")
        print(f"    Gold: {_preview_text(gold_sql, 260)}")


print("Spider eval preview helper ready.")
# Out:
# Spider eval preview helper ready.

# %% [markdown]
# ## 6) Baseline Evaluation on Spider

# %%
baseline_spider_eval = spider_test[:BASELINE_EVAL_SPIDER_N]

print("Baseline eval sample preview...")
preview_spider_eval_set(baseline_spider_eval, n=min(8, len(baseline_spider_eval)))

print("Loading baseline runtime...")
baseline_runtime = load_runtime(BASE_MODEL_ID)

print("Running baseline on spider with direct Spider execution evaluator...")
baseline_spider_report = evaluate_spider_direct_execution(
    baseline_runtime,
    baseline_spider_eval,
    progress_desc="Spider baseline direct eval",
    verbose=True,
    log_every=1,
    show_sql_preview=True,
)

print("Baseline spider execution accuracy (relaxed):", baseline_spider_report.get("execution_accuracy"))
print("Baseline spider execution accuracy (strict):", baseline_spider_report.get("strict_execution_accuracy"))
print_spider_eval_debug(baseline_spider_report, n=12)

# Release baseline runtime before training.
del baseline_runtime
clear_cuda()
# Out:
# Baseline eval sample preview...
# Previewing 8 Spider eval samples
# [1] db_id=dog_kennels db=ok gold_exec=ok
#     Q: Find the owner id and zip code of the owner who spent the most money in total for his or her dogs.
#     Gold: SELECT T1.owner_id , T1.zip_code FROM Owners AS T1 JOIN Dogs AS T2 ON T1.owner_id = T2.owner_id JOIN Treatments AS T3 ON T2.dog_id = T3.dog_id GROUP BY T1.owner_id ORDER BY sum(T3.cost_of_treatment) DESC LIMIT 1
# [2] db_id=course_teach db=ok gold_exec=ok
#     Q: What is the total count of teachers?
#     Gold: SELECT count(*) FROM teacher
# [3] db_id=cre_Doc_Template_Mgt db=ok gold_exec=ok
#     Q: Show the document id with paragraph text 'Brazil' and 'Ireland'.
#     Gold: SELECT document_id FROM Paragraphs WHERE paragraph_text = 'Brazil' INTERSECT SELECT document_id FROM Paragraphs WHERE paragraph_text = 'Ireland'
# [4] db_id=battle_death db=ok gold_exec=ok
#     Q: What is the ship id and name that caused most total injuries?
#     Gold: SELECT T2.id , T2.name FROM death AS T1 JOIN ship AS t2 ON T1.caused_by_ship_id = T2.id GROUP BY T2.id ORDER BY count(*) DESC LIMIT 1
# [5] db_id=cre_Doc_Template_Mgt db=ok gold_exec=ok
#     Q: Show all template type codes and descriptions.
#     Gold: SELECT template_type_code , template_type_description FROM Ref_template_types
# [6] db_id=employee_hire_evaluation db=ok gold_exec=ok
#     Q: Count the number of employees
#     Gold: SELECT count(*) FROM employee
# [7] db_id=car_1 db=ok gold_exec=ok
#     Q: What is the average weight of cars each year?
#     Gold: SELECT avg(Weight) , YEAR FROM CARS_DATA GROUP BY YEAR;
# [8] db_id=world_1 db=ok gold_exec=ok
#     Q: Which language is the most popular on the Asian continent?
#     Gold: SELECT T2.Language FROM country AS T1 JOIN countrylanguage AS T2 ON T1.Code = T2.CountryCode WHERE T1.Continent = "Asia" GROUP BY T2.Language ORDER BY COUNT (*) DESC LIMIT 1
# Loading baseline runtime...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/434 [00:00<?, ?it/s]
# Running baseline on spider with direct Spider execution evaluator...
# Spider baseline direct eval:   0%|          | 0/50 [00:00<?, ?query/s]
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [1/50] db_id=dog_kennels question=Find the owner id and zip code of the owner who spent the most money in total for his or her dogs.
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT T1.owner_id , T1.zip_code FROM Owners AS T1 JOIN Dogs AS T2 ON T1.owner_id = T2.owner_id JOIN Treatments AS T3 ON T2.dog_id = T3.dog_id GROUP BY T1.owner_id ORDER BY sum(...
#      pred_sql: SELECT O.owner_id, O.zip_code FROM Owners O JOIN ( SELECT T.dog_id, SUM(T.cost_of_treatment) AS total_spent FROM Treatments T GROUP BY T.dog_id ) AS TotalSpent ON O.owner_id = T...
# [2/50] db_id=course_teach question=What is the total count of teachers?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT count(*) FROM teacher
#      pred_sql: SELECT COUNT(*) FROM teacher;
# [3/50] db_id=cre_Doc_Template_Mgt question=Show the document id with paragraph text 'Brazil' and 'Ireland'.
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT document_id FROM Paragraphs WHERE paragraph_text = 'Brazil' INTERSECT SELECT document_id FROM Paragraphs WHERE paragraph_text = 'Ireland'
#      pred_sql: SELECT DISTINCT T1.Document_ID FROM Documents AS T1 JOIN Paragraphs AS T2 ON T1.Document_ID = T2.Document_ID WHERE T2.Paragraph_Text IN ('Brazil', 'Ireland');
# [4/50] db_id=battle_death question=What is the ship id and name that caused most total injuries?
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT T2.id , T2.name FROM death AS T1 JOIN ship AS t2 ON T1.caused_by_ship_id = T2.id GROUP BY T2.id ORDER BY count(*) DESC LIMIT 1
#      pred_sql: SELECT s.id, s.name FROM ship s JOIN death d ON s.id = d.caused_by_ship_id GROUP BY s.id, s.name ORDER BY SUM(d.injured) DESC LIMIT 1;
# [5/50] db_id=cre_Doc_Template_Mgt question=Show all template type codes and descriptions.
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT template_type_code , template_type_description FROM Ref_template_types
#      pred_sql: SELECT T1.Template_Type_Code, T1.Template_Type_Description FROM Ref_Template_Types AS T1 JOIN Templates AS T2 ON T1.Template_Type_Code = T2.Template_Type_Code;
# [6/50] db_id=employee_hire_evaluation question=Count the number of employees
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT count(*) FROM employee
#      pred_sql: SELECT COUNT(*) FROM employee;
# [7/50] db_id=car_1 question=What is the average weight of cars each year?
#   -> PASS | strict=PASS | match=actual_column_reordered | partial=1.00
#      gold_sql: SELECT avg(Weight) , YEAR FROM CARS_DATA GROUP BY YEAR;
#      pred_sql: SELECT YEAR, AVG(Weight) AS AverageWeight FROM cars_data GROUP BY YEAR;
# [8/50] db_id=world_1 question=Which language is the most popular on the Asian continent?
#   -> FAIL: predicted SQL execution error (no such column: T2.Language)
#      gold_sql: SELECT T2.Language FROM country AS T1 JOIN countrylanguage AS T2 ON T1.Code = T2.CountryCode WHERE T1.Continent = "Asia" GROUP BY T2.Language ORDER BY COUNT (*) DESC LIMIT 1
#      pred_sql: SELECT T2.Language FROM city AS T1 JOIN country AS T2 ON T1.CountryCode = T2.Code WHERE T2.Continent = 'Asia' GROUP BY T2.Language ORDER BY SUM(T1.Population) DESC LIMIT 1;
# [9/50] db_id=cre_Doc_Template_Mgt question=Show all paragraph texts for the document "Customer reviews".
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT T1.paragraph_text FROM Paragraphs AS T1 JOIN Documents AS T2 ON T1.document_id = T2.document_id WHERE T2.document_name = "Customer reviews"
#      pred_sql: SELECT T3.Paragraph_Text FROM Documents AS T1 JOIN Templates AS T2 ON T1.Template_ID = T2.Template_ID JOIN Paragraphs AS T3 ON T1.Document_ID = T3.Document_ID WHERE T1.Document_...
# [10/50] db_id=network_1 question=Show all the grades of the high schoolers.
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT grade FROM Highschooler
#      pred_sql: SELECT DISTINCT T1.grade FROM Highschooler AS T1 INNER JOIN Friend AS T2 ON T1.ID = T2.student_id;
# [11/50] db_id=poker_player question=List the earnings of poker players in descending order.
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT Earnings FROM poker_player ORDER BY Earnings DESC
#      pred_sql: SELECT T1.Earnings FROM poker_player AS T1 INNER JOIN people AS T2 ON T1.People_ID = T2.People_ID ORDER BY T1.Earnings DESC;
# [12/50] db_id=course_teach question=List the most common hometown of teachers.
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT Hometown FROM teacher GROUP BY Hometown ORDER BY COUNT(*) DESC LIMIT 1
#      pred_sql: SELECT T2.Hometown, COUNT(*) AS Frequency FROM course_arrange AS T1 JOIN teacher AS T2 ON T1.Teacher_ID = T2.Teacher_ID GROUP BY T2.Hometown ORDER BY Frequency DESC LIMIT 1;
# [13/50] db_id=orchestra question=What are years of founding for orchestras that have had more than a single performance?
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT Year_of_Founded FROM orchestra AS T1 JOIN performance AS T2 ON T1.Orchestra_ID = T2.Orchestra_ID GROUP BY T2.Orchestra_ID HAVING COUNT(*) > 1
#      pred_sql: SELECT DISTINCT T1.Year_of_Founded FROM orchestra AS T1 JOIN performance AS T2 ON T1.Orchestra_ID = T2.Orchestra_ID GROUP BY T1.Year_of_Founded HAVING COUNT(T2.Performance_ID) > 1;
# [14/50] db_id=poker_player question=What are the final tables made and best finishes for all poker players?
#   -> PASS | strict=PASS | match=actual_superset_projection | partial=1.00
#      gold_sql: SELECT Final_Table_Made , Best_Finish FROM poker_player
#      pred_sql: SELECT p.Name, p.Nationality, pp.Final_Table_Made, pp.Best_Finish FROM people p JOIN poker_player pp ON p.People_ID = pp.People_ID;
# [15/50] db_id=cre_Doc_Template_Mgt question=Return the id of the document with the fewest paragraphs.
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT document_id FROM Paragraphs GROUP BY document_id ORDER BY count(*) ASC LIMIT 1
#      pred_sql: SELECT T1.Document_ID FROM Documents AS T1 JOIN Paragraphs AS T2 ON T1.Document_ID = T2.Document_ID GROUP BY T1.Document_ID ORDER BY COUNT(T2.Paragraph_ID) ASC LIMIT 1;
# [16/50] db_id=singer question=What is the most common singer citizenship ?
#   -> PASS | strict=PASS | match=actual_superset_projection | partial=1.00
#      gold_sql: select citizenship from singer group by citizenship order by count(*) desc limit 1
#      pred_sql: SELECT Citizenship, COUNT(*) AS Common_Citizenship FROM singer GROUP BY Citizenship ORDER BY COUNT(*) DESC LIMIT 1;
# [17/50] db_id=poker_player question=What is the most common nationality of people?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT Nationality FROM people GROUP BY Nationality ORDER BY COUNT(*) DESC LIMIT 1
#      pred_sql: SELECT T2.Nationality FROM poker_player AS T1 INNER JOIN people AS T2 ON T1.People_ID = T2.People_ID GROUP BY T2.Nationality ORDER BY COUNT(*) DESC LIMIT 1;
# [18/50] db_id=network_1 question=Show the student IDs and numbers of friends corresponding to each.
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT student_id , count(*) FROM Friend GROUP BY student_id
#      pred_sql: SELECT T1.ID, COUNT(T2.student_id) AS number_of_friends FROM Highschooler AS T1 LEFT JOIN Friend AS T2 ON T1.ID = T2.student_id GROUP BY T1.ID;
# [19/50] db_id=pets_1 question=Find the id and weight of all pets whose age is older than 1.
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT petid , weight FROM pets WHERE pet_age > 1
#      pred_sql: SELECT P.PetID, P.weight FROM Pets P JOIN Has_Pet HP ON P.PetID = HP.PetID JOIN Student S ON HP.StuID = S.StuID WHERE P.pet_age > 1;
# [20/50] db_id=car_1 question=How many cars has over 6 cylinders?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT COUNT(*) FROM CARS_DATA WHERE Cylinders > 6;
#      pred_sql: SELECT COUNT(*) FROM cars_data WHERE Cylinders > 6;
# [21/50] db_id=singer question=Show the names of singers that have more than one song.
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT T1.Name FROM singer AS T1 JOIN song AS T2 ON T1.Singer_ID = T2.Singer_ID GROUP BY T1.Name HAVING COUNT(*) > 1
#      pred_sql: SELECT s.Name FROM singer s JOIN song ON s.Singer_ID = song.Singer_ID GROUP BY s.Singer_ID HAVING COUNT(song.Song_ID) > 1;
# [22/50] db_id=network_1 question=What is the name of the high schooler who has the greatest number of likes?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT T2.name FROM Likes AS T1 JOIN Highschooler AS T2 ON T1.student_id = T2.id GROUP BY T1.student_id ORDER BY count(*) DESC LIMIT 1
#      pred_sql: SELECT T1.name FROM Highschooler AS T1 JOIN ( SELECT student_id, COUNT(*) as like_count FROM Likes GROUP BY student_id ) AS T2 ON T1.ID = T2.student_id ORDER BY T2.like_count DE...
# [23/50] db_id=orchestra question=Return the names of conductors that do not have the nationality "USA".
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT Name FROM conductor WHERE Nationality != 'USA'
#      pred_sql: SELECT Name FROM conductor WHERE Nationality != 'USA';
# [24/50] db_id=course_teach question=List the names of teachers who have not been arranged to teach courses.
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT Name FROM teacher WHERE Teacher_id NOT IN (SELECT Teacher_id FROM course_arrange)
#      pred_sql: SELECT T2.Name FROM course AS T1 LEFT JOIN course_arrange AS T3 ON T1.Course_ID = T3.Course_ID LEFT JOIN teacher AS T2 ON T3.Teacher_ID = T2.Teacher_ID WHERE T3.Course_ID IS NULL;
# [25/50] db_id=car_1 question=What are all the makers and models?
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT Maker , Model FROM MODEL_LIST;
#      pred_sql: SELECT DISTINCT T1.Maker, T2.Model FROM car_makers AS T1 INNER JOIN model_list AS T2 ON T1.Id = T2.Maker;
# [26/50] db_id=dog_kennels question=Find the average age of the dogs who went through treatments.
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT avg(age) FROM Dogs WHERE dog_id IN ( SELECT dog_id FROM Treatments )
#      pred_sql: SELECT AVG(Dogs.age) FROM Dogs INNER JOIN Treatments ON Dogs.dog_id = Treatments.dog_id WHERE Dogs.date_departed IS NULL;
# [27/50] db_id=world_1 question=Count the number of countries for which Spanish is the predominantly spoken language.
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT count(*) , max(Percentage) FROM countrylanguage WHERE LANGUAGE = "Spanish" GROUP BY CountryCode
#      pred_sql: SELECT COUNT(T1.Name) FROM country AS T1 JOIN countrylanguage AS T2 ON T1.Code = T2.CountryCode WHERE T2.Language = 'Spanish' AND T2.IsOfficial = 1;
# [28/50] db_id=world_1 question=What are the names of the nations with the 3 lowest populations?
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT Name FROM country ORDER BY Population ASC LIMIT 3
#      pred_sql: SELECT T2.Name FROM city AS T1 JOIN country AS T2 ON T1.CountryCode = T2.Code GROUP BY T1.CountryCode ORDER BY T1.Population ASC LIMIT 3;
# [29/50] db_id=orchestra question=How many conductors are there?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT count(*) FROM conductor
#      pred_sql: SELECT COUNT(*) FROM conductor;
# [30/50] db_id=car_1 question=What is the name of each continent and how many car makers are there in each one?
#   -> FAIL: predicted SQL execution error (no such column: cm.CountryId)
#      gold_sql: SELECT T1.Continent , count(*) FROM CONTINENTS AS T1 JOIN COUNTRIES AS T2 ON T1.ContId = T2.continent JOIN car_makers AS T3 ON T2.CountryId = T3.Country GROUP BY T1.Continent;
#      pred_sql: SELECT c.Continent, COUNT(DISTINCT cm.FullName) AS CarMakersCount FROM continents c JOIN countries co ON c.ContId = co.Continent JOIN car_makers cm ON co.CountryId = cm.CountryI...
# [31/50] db_id=student_transcripts_tracking question=What is the zip code for Port Chelsea?
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT zip_postcode FROM Addresses WHERE city = 'Port Chelsea'
#      pred_sql: SELECT T1.zip_postcode FROM Addresses AS T1 JOIN Students AS T2 ON T1.address_id = T2.permanent_address_id WHERE T2.first_name = 'Port' AND T2.last_name = 'Chelsea';
# [32/50] db_id=flight_2 question=What is the code of airport that has fewest number of flights?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT T1.AirportCode FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode = T2.DestAirport OR T1.AirportCode = T2.SourceAirport GROUP BY T1.AirportCode ORDER BY count(*) LI...
#      pred_sql: SELECT T2.AirportCode, COUNT(*) AS FlightCount FROM flights AS T1 JOIN airports AS T2 ON T1.DestAirport = T2.AirportCode GROUP BY T2.AirportCode ORDER BY FlightCount ASC LIMIT 1;
# [33/50] db_id=car_1 question=Which distinctive models are produced by maker with the full name General Motors or weighing more than 3500?
#   -> FAIL: predicted SQL execution error (no such column: T3.MakeId)
#      gold_sql: SELECT DISTINCT T2.Model FROM CAR_NAMES AS T1 JOIN MODEL_LIST AS T2 ON T1.Model = T2.Model JOIN CAR_MAKERS AS T3 ON T2.Maker = T3.Id JOIN CARS_DATA AS T4 ON T1.MakeId = T4.Id WH...
#      pred_sql: SELECT DISTINCT T2.Model FROM car_makers AS T1 JOIN model_list AS T2 ON T1.Id = T2.Maker JOIN cars_data AS T3 ON T2.ModelId = T3.MakeId WHERE T1.FullName = 'General Motors' OR T...
# [34/50] db_id=employee_hire_evaluation question=What are the minimum and maximum number of products across all the shops?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT min(Number_products) , max(Number_products) FROM shop
#      pred_sql: SELECT MIN(Number_products) AS Min_Products, MAX(Number_products) AS Max_Products FROM shop;
# [35/50] db_id=world_1 question=What are the regions that use English or Dutch?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT DISTINCT T1.Region FROM country AS T1 JOIN countrylanguage AS T2 ON T1.Code = T2.CountryCode WHERE T2.Language = "English" OR T2.Language = "Dutch"
#      pred_sql: SELECT DISTINCT T1.Region FROM country AS T1 JOIN countrylanguage AS T2 ON T1.Code = T2.CountryCode WHERE T2.Language IN ('English', 'Dutch');
# [36/50] db_id=concert_singer question=Show the stadium name and the number of concerts in each stadium.
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT T2.name , count(*) FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id = T2.stadium_id GROUP BY T1.stadium_id
#      pred_sql: SELECT s.Name AS Stadium_Name, COUNT(*) AS Number_of_Concerts FROM stadium s JOIN concert c ON s.Stadium_ID = c.Stadium_ID GROUP BY s.Name;
# [37/50] db_id=dog_kennels question=List the date of each treatment, together with the first name of the professional who operated it.
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT T1.date_of_treatment , T2.first_name FROM Treatments AS T1 JOIN Professionals AS T2 ON T1.professional_id = T2.professional_id
#      pred_sql: SELECT T1.date_of_treatment, T3.first_name FROM Treatments AS T1 JOIN Dogs AS T2 ON T1.dog_id = T2.dog_id JOIN Professionals AS T3 ON T1.professional_id = T3.professional_id;
# [38/50] db_id=flight_2 question=Which airlines have departing flights from both APG and CVO airports?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid = T2.Airline WHERE T2.SourceAirport = "APG" INTERSECT SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2...
#      pred_sql: SELECT DISTINCT T1.Airline FROM airlines AS T1 JOIN flights AS T2 ON T1.uid = T2.Airline WHERE T2.SourceAirport = 'APG' AND T2.DestAirport = 'CVO';
# [39/50] db_id=voter_1 question=What is the area code in which the most voters voted?
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT T1.area_code FROM area_code_state AS T1 JOIN votes AS T2 ON T1.state = T2.state GROUP BY T1.area_code ORDER BY count(*) DESC LIMIT 1
#      pred_sql: SELECT T1.area_code FROM AREA_CODE_STATE AS T1 JOIN VOTES AS T2 ON T1.area_code = T2.state GROUP BY T1.area_code ORDER BY COUNT(T2.phone_number) DESC LIMIT 1;
# [40/50] db_id=wta_1 question=What is the best rank of losers across all matches?
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT min(loser_rank) FROM matches
#      pred_sql: SELECT MAX(loser_rank) FROM matches;
# [41/50] db_id=cre_Doc_Template_Mgt question=What are the ids for templates that are not used in any documents?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT template_id FROM Templates EXCEPT SELECT template_id FROM Documents
#      pred_sql: SELECT T1.Template_ID FROM Templates AS T1 LEFT JOIN Documents AS T2 ON T1.Template_ID = T2.Template_ID WHERE T2.Document_ID IS NULL;
# [42/50] db_id=museum_visit question=What are the id and name of the museum visited most times?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT t2.Museum_ID , t1.name FROM museum AS t1 JOIN visit AS t2 ON t1.Museum_ID = t2.Museum_ID GROUP BY t2.Museum_ID ORDER BY count(*) DESC LIMIT 1
#      pred_sql: SELECT m.Museum_ID, m.Name FROM museum m JOIN ( SELECT Museum_ID, COUNT(*) AS Visit_Count FROM visit GROUP BY Museum_ID ) v ON m.Museum_ID = v.Museum_ID ORDER BY Visit_Count DES...
# [43/50] db_id=orchestra question=How many different nationalities do conductors have?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT count(DISTINCT Nationality) FROM conductor
#      pred_sql: SELECT COUNT(DISTINCT Nationality) FROM conductor;
# [44/50] db_id=concert_singer question=What is the name and country of origin of every singer who has a song with the word 'Hey' in its title?
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT name , country FROM singer WHERE song_name LIKE '%Hey%'
#      pred_sql: SELECT s.Name, s.Country FROM singer s JOIN singer_in_concert sic ON s.Singer_ID = sic.Singer_ID JOIN concert c ON sic.concert_ID = c.concert_ID WHERE s.Song_Name LIKE '%Hey%';
# [45/50] db_id=cre_Doc_Template_Mgt question=What are the ids, version numbers, and type codes for each template?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT template_id , version_number , template_type_code FROM Templates
#      pred_sql: SELECT T1.Template_ID, T1.Version_Number, T1.Template_Type_Code FROM Templates AS T1 JOIN Ref_Template_Types AS T2 ON T1.Template_Type_Code = T2.Template_Type_Code;
# [46/50] db_id=car_1 question=What is the model of the car with the smallest amount of horsepower?
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT T1.Model FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId = T2.Id ORDER BY T2.horsepower ASC LIMIT 1;
#      pred_sql: SELECT T2.Model FROM cars_data AS T1 JOIN car_names AS T2 ON T1.Id = T2.MakeId JOIN model_list AS T3 ON T2.Model = T3.ModelId ORDER BY T1.Horsepower ASC LIMIT 1;
# [47/50] db_id=car_1 question=What is the horsepower of the car with the greatest accelerate?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT T1.horsepower FROM CARS_DATA AS T1 ORDER BY T1.accelerate DESC LIMIT 1;
#      pred_sql: SELECT T1.Horsepower FROM cars_data AS T1 JOIN car_names AS T2 ON T1.Id = T2.MakeId ORDER BY T1.Accelerate DESC LIMIT 1;
# [48/50] db_id=dog_kennels question=What is the description of the treatment type that costs the least money in total?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT T1.treatment_type_description FROM Treatment_types AS T1 JOIN Treatments AS T2 ON T1.treatment_type_code = T2.treatment_type_code GROUP BY T1.treatment_type_code ORDER BY...
#      pred_sql: SELECT T3.treatment_type_description FROM Treatments AS T1 JOIN Treatment_Types AS T3 ON T1.treatment_type_code = T3.treatment_type_code GROUP BY T3.treatment_type_description O...
# [49/50] db_id=poker_player question=List the names of people that are not poker players.
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT Name FROM people WHERE People_ID NOT IN (SELECT People_ID FROM poker_player)
#      pred_sql: SELECT T2.Name FROM poker_player AS T1 INNER JOIN people AS T2 ON T1.People_ID = T2.People_ID WHERE T1.Poker_Player_ID IS NULL;
# [50/50] db_id=orchestra question=What are the record companies that are used by both orchestras founded before 2003 and those founded after 2003?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT Record_Company FROM orchestra WHERE Year_of_Founded < 2003 INTERSECT SELECT Record_Company FROM orchestra WHERE Year_of_Founded > 2003
#      pred_sql: SELECT DISTINCT T1.Record_Company FROM orchestra AS T1 JOIN conductor AS T2 ON T1.Conductor_ID = T2.Conductor_ID WHERE T1.Year_of_Founded < 2003 INTERSECT SELECT DISTINCT T1.Rec...
# Baseline spider execution accuracy (relaxed): 0.58
# Baseline spider execution accuracy (strict): 0.58
# Spider eval debug summary: {'total': 50, 'passed': 29, 'failed': 21, 'errors': 0, 'pred_exec_errors': 3}
# Showing first 12 non-pass examples
# --------------------------------------------------------------------------------
# [1] db_id=dog_kennels outcome=FAIL strict=FAIL
# Q: Find the owner id and zip code of the owner who spent the most money in total for his or her dogs.
# Match type: none | Partial: 0.0
# Gold: SELECT T1.owner_id , T1.zip_code FROM Owners AS T1 JOIN Dogs AS T2 ON T1.owner_id = T2.owner_id JOIN Treatments AS T3 ON T2.dog_id = T3.dog_id GROUP BY T1.owner_id ORDER BY sum(T3.cost_of_treatment) DESC LIMIT 1
# Pred: SELECT O.owner_id, O.zip_code FROM Owners O JOIN ( SELECT T.dog_id, SUM(T.cost_of_treatment) AS total_spent FROM Treatments T GROUP BY T.dog_id ) AS TotalSpent ON O.owner_id = TotalSpent.dog_id ORDER BY TotalSpent.total_spent DESC LIMIT 1;
# --------------------------------------------------------------------------------
# [2] db_id=battle_death outcome=FAIL strict=FAIL
# Q: What is the ship id and name that caused most total injuries?
# Match type: none | Partial: 0.0
# Gold: SELECT T2.id , T2.name FROM death AS T1 JOIN ship AS t2 ON T1.caused_by_ship_id = T2.id GROUP BY T2.id ORDER BY count(*) DESC LIMIT 1
# Pred: SELECT s.id, s.name FROM ship s JOIN death d ON s.id = d.caused_by_ship_id GROUP BY s.id, s.name ORDER BY SUM(d.injured) DESC LIMIT 1;
# --------------------------------------------------------------------------------
# [3] db_id=cre_Doc_Template_Mgt outcome=FAIL strict=FAIL
# Q: Show all template type codes and descriptions.
# Match type: none | Partial: 0.0
# Gold: SELECT template_type_code , template_type_description FROM Ref_template_types
# Pred: SELECT T1.Template_Type_Code, T1.Template_Type_Description FROM Ref_Template_Types AS T1 JOIN Templates AS T2 ON T1.Template_Type_Code = T2.Template_Type_Code;
# --------------------------------------------------------------------------------
# [4] db_id=world_1 outcome=FAIL strict=FAIL
# Q: Which language is the most popular on the Asian continent?
# Error: no such column: T2.Language
# Match type: none | Partial: 0.0
# Gold: SELECT T2.Language FROM country AS T1 JOIN countrylanguage AS T2 ON T1.Code = T2.CountryCode WHERE T1.Continent = "Asia" GROUP BY T2.Language ORDER BY COUNT (*) DESC LIMIT 1
# Pred: SELECT T2.Language FROM city AS T1 JOIN country AS T2 ON T1.CountryCode = T2.Code WHERE T2.Continent = 'Asia' GROUP BY T2.Language ORDER BY SUM(T1.Population) DESC LIMIT 1;
# --------------------------------------------------------------------------------
# [5] db_id=network_1 outcome=FAIL strict=FAIL
# Q: Show all the grades of the high schoolers.
# Match type: none | Partial: 0.0
# Gold: SELECT grade FROM Highschooler
# Pred: SELECT DISTINCT T1.grade FROM Highschooler AS T1 INNER JOIN Friend AS T2 ON T1.ID = T2.student_id;
# --------------------------------------------------------------------------------
# [6] db_id=course_teach outcome=FAIL strict=FAIL
# Q: List the most common hometown of teachers.
# Match type: none | Partial: 0.0
# Gold: SELECT Hometown FROM teacher GROUP BY Hometown ORDER BY COUNT(*) DESC LIMIT 1
# Pred: SELECT T2.Hometown, COUNT(*) AS Frequency FROM course_arrange AS T1 JOIN teacher AS T2 ON T1.Teacher_ID = T2.Teacher_ID GROUP BY T2.Hometown ORDER BY Frequency DESC LIMIT 1;
# --------------------------------------------------------------------------------
# [7] db_id=orchestra outcome=FAIL strict=FAIL
# Q: What are years of founding for orchestras that have had more than a single performance?
# Match type: none | Partial: 0.0
# Gold: SELECT Year_of_Founded FROM orchestra AS T1 JOIN performance AS T2 ON T1.Orchestra_ID = T2.Orchestra_ID GROUP BY T2.Orchestra_ID HAVING COUNT(*) > 1
# Pred: SELECT DISTINCT T1.Year_of_Founded FROM orchestra AS T1 JOIN performance AS T2 ON T1.Orchestra_ID = T2.Orchestra_ID GROUP BY T1.Year_of_Founded HAVING COUNT(T2.Performance_ID) > 1;
# --------------------------------------------------------------------------------
# [8] db_id=network_1 outcome=FAIL strict=FAIL
# Q: Show the student IDs and numbers of friends corresponding to each.
# Match type: none | Partial: 0.0
# Gold: SELECT student_id , count(*) FROM Friend GROUP BY student_id
# Pred: SELECT T1.ID, COUNT(T2.student_id) AS number_of_friends FROM Highschooler AS T1 LEFT JOIN Friend AS T2 ON T1.ID = T2.student_id GROUP BY T1.ID;
# --------------------------------------------------------------------------------
# [9] db_id=course_teach outcome=FAIL strict=FAIL
# Q: List the names of teachers who have not been arranged to teach courses.
# Match type: none | Partial: 0.0
# Gold: SELECT Name FROM teacher WHERE Teacher_id NOT IN (SELECT Teacher_id FROM course_arrange)
# Pred: SELECT T2.Name FROM course AS T1 LEFT JOIN course_arrange AS T3 ON T1.Course_ID = T3.Course_ID LEFT JOIN teacher AS T2 ON T3.Teacher_ID = T2.Teacher_ID WHERE T3.Course_ID IS NULL;
# --------------------------------------------------------------------------------
# [10] db_id=car_1 outcome=FAIL strict=FAIL
# Q: What are all the makers and models?
# Match type: none | Partial: 0.0
# Gold: SELECT Maker , Model FROM MODEL_LIST;
# Pred: SELECT DISTINCT T1.Maker, T2.Model FROM car_makers AS T1 INNER JOIN model_list AS T2 ON T1.Id = T2.Maker;
# --------------------------------------------------------------------------------
# [11] db_id=dog_kennels outcome=FAIL strict=FAIL
# Q: Find the average age of the dogs who went through treatments.
# Match type: none | Partial: 0.0
# Gold: SELECT avg(age) FROM Dogs WHERE dog_id IN ( SELECT dog_id FROM Treatments )
# Pred: SELECT AVG(Dogs.age) FROM Dogs INNER JOIN Treatments ON Dogs.dog_id = Treatments.dog_id WHERE Dogs.date_departed IS NULL;
# --------------------------------------------------------------------------------
# [12] db_id=world_1 outcome=FAIL strict=FAIL
# Q: Count the number of countries for which Spanish is the predominantly spoken language.
# Match type: none | Partial: 0.0
# Gold: SELECT count(*) , max(Percentage) FROM countrylanguage WHERE LANGUAGE = "Spanish" GROUP BY CountryCode
# Pred: SELECT COUNT(T1.Name) FROM country AS T1 JOIN countrylanguage AS T2 ON T1.Code = T2.CountryCode WHERE T2.Language = 'Spanish' AND T2.IsOfficial = 1;

# %% [markdown]
# ## 7) Training Utilities for QLoRA Adapter Fine-Tuning

# %%
def format_company_train_text(item: dict) -> str:

    prompt = company_prompt(item["question"])

    return f"{prompt}\n{item['sql']}"





def format_spider_train_text(item: dict) -> str:

    prompt = spider_prompt(item)

    gold_sql = item.get("query", "")

    return f"{prompt}\n{gold_sql}"





def make_text_dataset(samples, formatter):

    rows = [{"text": formatter(s)} for s in samples]

    return Dataset.from_list(rows)





def train_adapter(

    adapter_name: str,

    train_samples,

    val_samples,

    formatter,

    output_dir: Path,

    num_train_epochs: int = 1,

    max_steps: int = -1,

    learning_rate: float = 5e-5,

):

    output_dir = Path(output_dir)

    output_dir.mkdir(parents=True, exist_ok=True)



    compute_dtype = torch.bfloat16 if torch.cuda.is_available() and torch.cuda.is_bf16_supported() else torch.float16

    bnb_config = BitsAndBytesConfig(

        load_in_4bit=True,

        bnb_4bit_quant_type="nf4",

        bnb_4bit_compute_dtype=compute_dtype,

        bnb_4bit_use_double_quant=True,

    )



    tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL_ID, trust_remote_code=True)

    if tokenizer.pad_token is None:

        tokenizer.pad_token = tokenizer.eos_token



    model = AutoModelForCausalLM.from_pretrained(

        BASE_MODEL_ID,

        quantization_config=bnb_config,

        device_map="auto",

        trust_remote_code=True,

    )

    model.config.use_cache = False

    model.gradient_checkpointing_enable()

    model = prepare_model_for_kbit_training(model)



    lora_config = LoraConfig(

        r=16,

        lora_alpha=32,

        lora_dropout=0.05,

        bias="none",

        task_type="CAUSAL_LM",

        target_modules=["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"],

    )

    model = get_peft_model(model, lora_config)

    model.print_trainable_parameters()



    train_ds = make_text_dataset(train_samples, formatter)

    val_ds = make_text_dataset(val_samples, formatter) if val_samples else None



    def tok(batch):

        return tokenizer(batch["text"], truncation=True, max_length=MAX_SEQ_LEN)



    train_tok = train_ds.map(tok, batched=True, remove_columns=["text"])

    val_tok = val_ds.map(tok, batched=True, remove_columns=["text"]) if val_ds is not None else None



    collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)



    args_kwargs = {

        "output_dir": str(output_dir),

        "per_device_train_batch_size": 1,

        "gradient_accumulation_steps": 8,

        "learning_rate": learning_rate,

        "num_train_epochs": num_train_epochs,

        "max_steps": max_steps,

        "logging_steps": 10,

        "save_strategy": "epoch",

        "optim": "paged_adamw_8bit",

        "gradient_checkpointing": True,

        "report_to": "none",
        "disable_tqdm": False,

        "fp16": compute_dtype == torch.float16,

        "bf16": compute_dtype == torch.bfloat16,

    }



    has_eval = val_tok is not None and len(val_tok) > 0

    ta_params = inspect.signature(TrainingArguments.__init__).parameters

    if has_eval:

        if "evaluation_strategy" in ta_params:

            args_kwargs["evaluation_strategy"] = "epoch"

        elif "eval_strategy" in ta_params:

            args_kwargs["eval_strategy"] = "epoch"

        args_kwargs["per_device_eval_batch_size"] = 1



    train_args = TrainingArguments(**args_kwargs)



    trainer = Trainer(

        model=model,

        args=train_args,

        train_dataset=train_tok,

        eval_dataset=val_tok if has_eval else None,

        data_collator=collator,

    )



    print(f"Training adapter: {adapter_name}")

    trainer.train()



    final_adapter = output_dir / "final_adapter"

    trainer.model.save_pretrained(final_adapter)

    tokenizer.save_pretrained(final_adapter)



    del trainer

    del model

    clear_cuda()



    print(f"Saved adapter [{adapter_name}] to: {final_adapter}")

    return final_adapter

# %%
# Spider-specific training function aligned with chat-template inference format.
def train_spider_adapter_chat(
    adapter_name: str,
    train_samples,
    val_samples,
    output_dir: Path,
    num_train_epochs: int = 2,
    max_steps: int = -1,
    learning_rate: float = 1e-4,
):
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

    compute_dtype = torch.bfloat16 if torch.cuda.is_available() and torch.cuda.is_bf16_supported() else torch.float16
    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=True,
    )

    tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL_ID, trust_remote_code=True)
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token

    model = AutoModelForCausalLM.from_pretrained(
        BASE_MODEL_ID,
        quantization_config=bnb_config,
        device_map="auto",
        trust_remote_code=True,
    )
    model.config.use_cache = False
    model.gradient_checkpointing_enable()
    model = prepare_model_for_kbit_training(model)

    lora_config = LoraConfig(
        r=16,
        lora_alpha=32,
        lora_dropout=0.05,
        bias="none",
        task_type="CAUSAL_LM",
        target_modules=["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"],
    )
    model = get_peft_model(model, lora_config)
    model.print_trainable_parameters()

    def _to_chat_text(item: dict) -> str:
        prompt = spider_prompt(item)
        gold_sql = item.get("query", "").strip()
        if hasattr(tokenizer, "apply_chat_template"):
            messages = [
                {"role": "system", "content": "Return only SQL."},
                {"role": "user", "content": prompt},
                {"role": "assistant", "content": gold_sql},
            ]
            return tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=False)
        return f"{prompt}\n{gold_sql}"

    train_ds = Dataset.from_list([{"text": _to_chat_text(s)} for s in train_samples])
    val_ds = Dataset.from_list([{"text": _to_chat_text(s)} for s in val_samples]) if val_samples else None

    def tok(batch):
        return tokenizer(batch["text"], truncation=True, max_length=MAX_SEQ_LEN)

    train_tok = train_ds.map(tok, batched=True, remove_columns=["text"])
    val_tok = val_ds.map(tok, batched=True, remove_columns=["text"]) if val_ds is not None else None

    collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)

    args_kwargs = {
        "output_dir": str(output_dir),
        "per_device_train_batch_size": 1,
        "gradient_accumulation_steps": 8,
        "learning_rate": learning_rate,
        "num_train_epochs": num_train_epochs,
        "max_steps": max_steps,
        "logging_steps": 10,
        "save_strategy": "epoch",
        "optim": "paged_adamw_8bit",
        "gradient_checkpointing": True,
        "report_to": "none",
        "disable_tqdm": False,
        "fp16": compute_dtype == torch.float16,
        "bf16": compute_dtype == torch.bfloat16,
    }

    has_eval = val_tok is not None and len(val_tok) > 0
    ta_params = inspect.signature(TrainingArguments.__init__).parameters
    if has_eval:
        if "evaluation_strategy" in ta_params:
            args_kwargs["evaluation_strategy"] = "epoch"
        elif "eval_strategy" in ta_params:
            args_kwargs["eval_strategy"] = "epoch"
        args_kwargs["per_device_eval_batch_size"] = 1

    train_args = TrainingArguments(**args_kwargs)
    trainer = Trainer(
        model=model,
        args=train_args,
        train_dataset=train_tok,
        eval_dataset=val_tok if has_eval else None,
        data_collator=collator,
    )

    print(f"Training adapter: {adapter_name} (chat-template aligned)")
    trainer.train()

    final_adapter = output_dir / "final_adapter"
    trainer.model.save_pretrained(final_adapter)
    tokenizer.save_pretrained(final_adapter)

    del trainer
    del model
    clear_cuda()

    print(f"Saved adapter [{adapter_name}] to: {final_adapter}")
    return final_adapter


print("Spider chat-template training function ready.")
# Out:
# Spider chat-template training function ready.

# %%
# T4-focused training defaults (spider-only)
SPIDER_TRAIN_EPOCHS = 1
SPIDER_LEARNING_RATE = 1e-4
SPIDER_MAX_STEPS = -1

# Optional longer run profile (if validation stays stable).
SPIDER_TRAIN_EPOCHS_ALT = 2
SPIDER_LEARNING_RATE_ALT = 8e-5

print("T4 profile:")
print({
    "spider": {"epochs": SPIDER_TRAIN_EPOCHS, "lr": SPIDER_LEARNING_RATE},
    "alt": {"epochs": SPIDER_TRAIN_EPOCHS_ALT, "lr": SPIDER_LEARNING_RATE_ALT},
    "note": "Use 1 epoch first; only extend if eval improves.",
})
# Out:
# T4 profile:
# {'spider': {'epochs': 1, 'lr': 0.0001}, 'alt': {'epochs': 2, 'lr': 8e-05}, 'note': 'Use 1 epoch first; only extend if eval improves.'}

# %% [markdown]
# ### T4 QLoRA Hyperparameter Profile
#
# Recommended for this notebook run profile:
# - Start with `1e-4` for `1` epoch on `4000` Spider train samples
# - If eval improves and remains stable, try the alt profile (`2` epochs, `8e-5`)
# - If outputs become unstable, reduce LR to `5e-5`
# - `5e-1` is far too high and will diverge
#
# Use validation/eval metrics to decide whether to extend beyond one epoch.

# %% [markdown]
# ## 8) Fine-Tune Spider Adapter, Then Evaluate

# %%
spider_adapter_dir = train_spider_adapter_chat(
    adapter_name="spider",
    train_samples=spider_train,
    val_samples=spider_val,
    output_dir=OUTPUT_ROOT / "spider_adapter",
    num_train_epochs=SPIDER_TRAIN_EPOCHS,
    max_steps=SPIDER_MAX_STEPS,
    learning_rate=SPIDER_LEARNING_RATE,
)

spider_runtime = load_runtime(BASE_MODEL_ID, adapter_path=spider_adapter_dir)
spider_ft_eval_set = spider_test[:FT_EVAL_SPIDER_N]

print("Adapter eval sample preview...")
preview_spider_eval_set(spider_ft_eval_set, n=min(8, len(spider_ft_eval_set)))

spider_ft_spider_report = evaluate_spider_direct_execution(
    spider_runtime,
    spider_ft_eval_set,
    progress_desc="Spider adapter direct eval",
    verbose=True,
    log_every=1,
    show_sql_preview=True,
)

print("Spider adapter on spider execution accuracy (relaxed):", spider_ft_spider_report.get("execution_accuracy"))
print("Spider adapter on spider execution accuracy (strict):", spider_ft_spider_report.get("strict_execution_accuracy"))
print_spider_eval_debug(spider_ft_spider_report, n=12)

del spider_runtime
clear_cuda()
# Out:
# Loading weights:   0%|          | 0/434 [00:00<?, ?it/s]
# trainable params: 29,933,568 || all params: 3,115,872,256 || trainable%: 0.9607
# Map:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]
# Training adapter: spider (chat-template aligned)
#     <div>
#
#       <progress value='313' max='313' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [313/313 2:44:26, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.144310</td>
#       <td>0.997520</td>
#     </tr>
#   </tbody>
# </table><p>
# Saved adapter [spider] to: /content/outputs/dual_adapters/spider_adapter/final_adapter
# Loading weights:   0%|          | 0/434 [00:00<?, ?it/s]
# Adapter eval sample preview...
# Previewing 8 Spider eval samples
# [1] db_id=dog_kennels db=ok gold_exec=ok
#     Q: Find the owner id and zip code of the owner who spent the most money in total for his or her dogs.
#     Gold: SELECT T1.owner_id , T1.zip_code FROM Owners AS T1 JOIN Dogs AS T2 ON T1.owner_id = T2.owner_id JOIN Treatments AS T3 ON T2.dog_id = T3.dog_id GROUP BY T1.owner_id ORDER BY sum(T3.cost_of_treatment) DESC LIMIT 1
# [2] db_id=course_teach db=ok gold_exec=ok
#     Q: What is the total count of teachers?
#     Gold: SELECT count(*) FROM teacher
# [3] db_id=cre_Doc_Template_Mgt db=ok gold_exec=ok
#     Q: Show the document id with paragraph text 'Brazil' and 'Ireland'.
#     Gold: SELECT document_id FROM Paragraphs WHERE paragraph_text = 'Brazil' INTERSECT SELECT document_id FROM Paragraphs WHERE paragraph_text = 'Ireland'
# [4] db_id=battle_death db=ok gold_exec=ok
#     Q: What is the ship id and name that caused most total injuries?
#     Gold: SELECT T2.id , T2.name FROM death AS T1 JOIN ship AS t2 ON T1.caused_by_ship_id = T2.id GROUP BY T2.id ORDER BY count(*) DESC LIMIT 1
# [5] db_id=cre_Doc_Template_Mgt db=ok gold_exec=ok
#     Q: Show all template type codes and descriptions.
#     Gold: SELECT template_type_code , template_type_description FROM Ref_template_types
# [6] db_id=employee_hire_evaluation db=ok gold_exec=ok
#     Q: Count the number of employees
#     Gold: SELECT count(*) FROM employee
# [7] db_id=car_1 db=ok gold_exec=ok
#     Q: What is the average weight of cars each year?
#     Gold: SELECT avg(Weight) , YEAR FROM CARS_DATA GROUP BY YEAR;
# [8] db_id=world_1 db=ok gold_exec=ok
#     Q: Which language is the most popular on the Asian continent?
#     Gold: SELECT T2.Language FROM country AS T1 JOIN countrylanguage AS T2 ON T1.Code = T2.CountryCode WHERE T1.Continent = "Asia" GROUP BY T2.Language ORDER BY COUNT (*) DESC LIMIT 1
# Spider adapter direct eval:   0%|          | 0/50 [00:00<?, ?query/s]
# [1/50] db_id=dog_kennels question=Find the owner id and zip code of the owner who spent the most money in total for his or her dogs.
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT T1.owner_id , T1.zip_code FROM Owners AS T1 JOIN Dogs AS T2 ON T1.owner_id = T2.owner_id JOIN Treatments AS T3 ON T2.dog_id = T3.dog_id GROUP BY T1.owner_id ORDER BY sum(...
#      pred_sql: SELECT T1.owner_id , T1.zip_code FROM owners AS T1 JOIN treatments AS T2 ON T1.owner_id = T2.dog_id GROUP BY T1.owner_id ORDER BY sum(T2.cost_of_treatment) DESC LIMIT 1;
# [2/50] db_id=course_teach question=What is the total count of teachers?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT count(*) FROM teacher
#      pred_sql: SELECT count(*) FROM teacher;
# [3/50] db_id=cre_Doc_Template_Mgt question=Show the document id with paragraph text 'Brazil' and 'Ireland'.
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT document_id FROM Paragraphs WHERE paragraph_text = 'Brazil' INTERSECT SELECT document_id FROM Paragraphs WHERE paragraph_text = 'Ireland'
#      pred_sql: SELECT document_id FROM paragraphs WHERE paragraph_text = "Brazil" INTERSECT SELECT document_id FROM paragraphs WHERE paragraph_text = "Ireland";
# [4/50] db_id=battle_death question=What is the ship id and name that caused most total injuries?
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT T2.id , T2.name FROM death AS T1 JOIN ship AS t2 ON T1.caused_by_ship_id = T2.id GROUP BY T2.id ORDER BY count(*) DESC LIMIT 1
#      pred_sql: SELECT T1.id , T1.name FROM ship AS T1 JOIN death AS T2 ON T1.id = T2.caused_by_ship_id GROUP BY T1.id ORDER BY sum(T2.injured) DESC LIMIT 1;
# [5/50] db_id=cre_Doc_Template_Mgt question=Show all template type codes and descriptions.
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT template_type_code , template_type_description FROM Ref_template_types
#      pred_sql: SELECT Template_Type_Code , Template_Type_Description FROM Ref_Template_Types;
# [6/50] db_id=employee_hire_evaluation question=Count the number of employees
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT count(*) FROM employee
#      pred_sql: SELECT count(*) FROM employee;
# [7/50] db_id=car_1 question=What is the average weight of cars each year?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT avg(Weight) , YEAR FROM CARS_DATA GROUP BY YEAR;
#      pred_sql: SELECT avg(Weight) , YEAR FROM cars_data GROUP BY YEAR;
# [8/50] db_id=world_1 question=Which language is the most popular on the Asian continent?
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT T2.Language FROM country AS T1 JOIN countrylanguage AS T2 ON T1.Code = T2.CountryCode WHERE T1.Continent = "Asia" GROUP BY T2.Language ORDER BY COUNT (*) DESC LIMIT 1
#      pred_sql: SELECT T2.Language FROM country AS T1 JOIN countrylanguage AS T2 ON T1.Code = T2.CountryCode WHERE T1.Continent = 'Asia' ORDER BY T2.Percentage DESC LIMIT 1;
# [9/50] db_id=cre_Doc_Template_Mgt question=Show all paragraph texts for the document "Customer reviews".
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT T1.paragraph_text FROM Paragraphs AS T1 JOIN Documents AS T2 ON T1.document_id = T2.document_id WHERE T2.document_name = "Customer reviews"
#      pred_sql: SELECT T1.paragraph_text FROM paragraphs AS T1 JOIN documents AS T2 ON T1.document_id = T2.document_id WHERE T2.document_name = "Customer reviews";
# [10/50] db_id=network_1 question=Show all the grades of the high schoolers.
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT grade FROM Highschooler
#      pred_sql: SELECT grade FROM Highschooler;
# [11/50] db_id=poker_player question=List the earnings of poker players in descending order.
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT Earnings FROM poker_player ORDER BY Earnings DESC
#      pred_sql: SELECT Earnings FROM poker_player ORDER BY Earnings DESC;
# [12/50] db_id=course_teach question=List the most common hometown of teachers.
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT Hometown FROM teacher GROUP BY Hometown ORDER BY COUNT(*) DESC LIMIT 1
#      pred_sql: SELECT Hometown FROM teacher GROUP BY Hometown ORDER BY count(*) DESC LIMIT 1;
# [13/50] db_id=orchestra question=What are years of founding for orchestras that have had more than a single performance?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT Year_of_Founded FROM orchestra AS T1 JOIN performance AS T2 ON T1.Orchestra_ID = T2.Orchestra_ID GROUP BY T2.Orchestra_ID HAVING COUNT(*) > 1
#      pred_sql: SELECT YEAR_OF_FOUNDED FROM ORCHESTRA WHERE CONDUCTOR_ID IN (SELECT CONDUCTOR_ID FROM CONDUCTOR GROUP BY CONDUCTOR_ID HAVING COUNT(*) > 1);
# [14/50] db_id=poker_player question=What are the final tables made and best finishes for all poker players?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT Final_Table_Made , Best_Finish FROM poker_player
#      pred_sql: SELECT T1.Final_Table_Made , T1.Best_Finish FROM poker_player AS T1 JOIN people AS T2 ON T1.People_ID = T2.People_ID;
# [15/50] db_id=cre_Doc_Template_Mgt question=Return the id of the document with the fewest paragraphs.
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT document_id FROM Paragraphs GROUP BY document_id ORDER BY count(*) ASC LIMIT 1
#      pred_sql: SELECT document_id FROM documents GROUP BY document_id ORDER BY count(*) ASC LIMIT 1;
# [16/50] db_id=singer question=What is the most common singer citizenship ?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: select citizenship from singer group by citizenship order by count(*) desc limit 1
#      pred_sql: SELECT Citizenship FROM singer GROUP BY Citizenship ORDER BY count(*) DESC LIMIT 1;
# [17/50] db_id=poker_player question=What is the most common nationality of people?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT Nationality FROM people GROUP BY Nationality ORDER BY COUNT(*) DESC LIMIT 1
#      pred_sql: SELECT Nationality FROM people GROUP BY Nationality ORDER BY COUNT(*) DESC LIMIT 1;
# [18/50] db_id=network_1 question=Show the student IDs and numbers of friends corresponding to each.
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT student_id , count(*) FROM Friend GROUP BY student_id
#      pred_sql: SELECT T1.id , count(*) FROM highschooler AS T1 JOIN friend AS T2 ON T1.id = T2.student_id GROUP BY T1.id;
# [19/50] db_id=pets_1 question=Find the id and weight of all pets whose age is older than 1.
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT petid , weight FROM pets WHERE pet_age > 1
#      pred_sql: SELECT PetID , weight FROM Pets WHERE pet_age > 1;
# [20/50] db_id=car_1 question=How many cars has over 6 cylinders?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT COUNT(*) FROM CARS_DATA WHERE Cylinders > 6;
#      pred_sql: SELECT count(*) FROM cars_data WHERE Cylinders > 6;
# [21/50] db_id=singer question=Show the names of singers that have more than one song.
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT T1.Name FROM singer AS T1 JOIN song AS T2 ON T1.Singer_ID = T2.Singer_ID GROUP BY T1.Name HAVING COUNT(*) > 1
#      pred_sql: SELECT T1.Name FROM singer AS T1 JOIN song AS T2 ON T1.Singer_ID = T2.Singer_ID GROUP BY T1.Singer_ID HAVING count(*) > 1;
# [22/50] db_id=network_1 question=What is the name of the high schooler who has the greatest number of likes?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT T2.name FROM Likes AS T1 JOIN Highschooler AS T2 ON T1.student_id = T2.id GROUP BY T1.student_id ORDER BY count(*) DESC LIMIT 1
#      pred_sql: SELECT T1.name FROM Highschooler AS T1 JOIN Likes AS T2 ON T1.id = T2.student_id GROUP BY T2.student_id ORDER BY count(*) DESC LIMIT 1;
# [23/50] db_id=orchestra question=Return the names of conductors that do not have the nationality "USA".
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT Name FROM conductor WHERE Nationality != 'USA'
#      pred_sql: SELECT name FROM conductor WHERE nationality != "USA";
# [24/50] db_id=course_teach question=List the names of teachers who have not been arranged to teach courses.
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT Name FROM teacher WHERE Teacher_id NOT IN (SELECT Teacher_id FROM course_arrange)
#      pred_sql: SELECT name FROM teacher WHERE teacher_id NOT IN (SELECT teacher_id FROM course_arrange);
# [25/50] db_id=car_1 question=What are all the makers and models?
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT Maker , Model FROM MODEL_LIST;
#      pred_sql: SELECT DISTINCT T1.Maker , T1.Model FROM model_list AS T1 JOIN car_makers AS T2 ON T1.Maker = T2.Id;
# [26/50] db_id=dog_kennels question=Find the average age of the dogs who went through treatments.
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT avg(age) FROM Dogs WHERE dog_id IN ( SELECT dog_id FROM Treatments )
#      pred_sql: SELECT avg(T1.age) FROM Dogs AS T1 JOIN Treatments AS T2 ON T1.dog_id = T2.dog_id;
# [27/50] db_id=world_1 question=Count the number of countries for which Spanish is the predominantly spoken language.
#   -> FAIL: predicted SQL execution error (no such column: Language)
#      gold_sql: SELECT count(*) , max(Percentage) FROM countrylanguage WHERE LANGUAGE = "Spanish" GROUP BY CountryCode
#      pred_sql: SELECT count(*) FROM country WHERE Language = 'Spanish';
# [28/50] db_id=world_1 question=What are the names of the nations with the 3 lowest populations?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT Name FROM country ORDER BY Population ASC LIMIT 3
#      pred_sql: SELECT Name FROM country ORDER BY Population LIMIT 3;
# [29/50] db_id=orchestra question=How many conductors are there?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT count(*) FROM conductor
#      pred_sql: SELECT count(*) FROM conductor;
# [30/50] db_id=car_1 question=What is the name of each continent and how many car makers are there in each one?
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT T1.Continent , count(*) FROM CONTINENTS AS T1 JOIN COUNTRIES AS T2 ON T1.ContId = T2.continent JOIN car_makers AS T3 ON T2.CountryId = T3.Country GROUP BY T1.Continent;
#      pred_sql: SELECT T1.continent , count(*) FROM countries AS T1 JOIN car_makers AS T2 ON T1.countryid = T2.country GROUP BY T1.continent;
# [31/50] db_id=student_transcripts_tracking question=What is the zip code for Port Chelsea?
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT zip_postcode FROM Addresses WHERE city = 'Port Chelsea'
#      pred_sql: SELECT T1.zip_postcode FROM addresses AS T1 JOIN students AS T2 ON T1.address_id = T2.permanent_address_id WHERE T2.first_name = "Port" AND T2.last_name = "Chelsea";
# [32/50] db_id=flight_2 question=What is the code of airport that has fewest number of flights?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT T1.AirportCode FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode = T2.DestAirport OR T1.AirportCode = T2.SourceAirport GROUP BY T1.AirportCode ORDER BY count(*) LI...
#      pred_sql: SELECT T1.AirportCode FROM airports AS T1 JOIN flights AS T2 ON T1.AirportCode = T2.DestAirport GROUP BY T1.AirportCode ORDER BY count(*) ASC LIMIT 1;
# [33/50] db_id=car_1 question=Which distinctive models are produced by maker with the full name General Motors or weighing more than 3500?
#   -> FAIL: predicted SQL execution error (no such column: T1.Weight)
#      gold_sql: SELECT DISTINCT T2.Model FROM CAR_NAMES AS T1 JOIN MODEL_LIST AS T2 ON T1.Model = T2.Model JOIN CAR_MAKERS AS T3 ON T2.Maker = T3.Id JOIN CARS_DATA AS T4 ON T1.MakeId = T4.Id WH...
#      pred_sql: SELECT DISTINCT T1.Model FROM model_list AS T1 JOIN car_makers AS T2 ON T1.Maker = T2.Id WHERE T2.FullName = "General Motors" OR T1.Weight > 3500;
# [34/50] db_id=employee_hire_evaluation question=What are the minimum and maximum number of products across all the shops?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT min(Number_products) , max(Number_products) FROM shop
#      pred_sql: SELECT min(Number_products) , max(Number_products) FROM SHOP;
# [35/50] db_id=world_1 question=What are the regions that use English or Dutch?
#   -> FAIL: predicted SQL execution error (no such column: language)
#      gold_sql: SELECT DISTINCT T1.Region FROM country AS T1 JOIN countrylanguage AS T2 ON T1.Code = T2.CountryCode WHERE T2.Language = "English" OR T2.Language = "Dutch"
#      pred_sql: SELECT DISTINCT region FROM country WHERE language = 'English' OR language = 'Dutch';
# [36/50] db_id=concert_singer question=Show the stadium name and the number of concerts in each stadium.
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT T2.name , count(*) FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id = T2.stadium_id GROUP BY T1.stadium_id
#      pred_sql: SELECT T1.Name , count(*) FROM stadium AS T1 JOIN concert AS T2 ON T1.Stadium_ID = T2.Stadium_ID GROUP BY T1.Name;
# [37/50] db_id=dog_kennels question=List the date of each treatment, together with the first name of the professional who operated it.
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT T1.date_of_treatment , T2.first_name FROM Treatments AS T1 JOIN Professionals AS T2 ON T1.professional_id = T2.professional_id
#      pred_sql: SELECT T1.date_of_treatment , T2.first_name FROM Treatments AS T1 JOIN Professionals AS T2 ON T1.professional_id = T2.professional_id;
# [38/50] db_id=flight_2 question=Which airlines have departing flights from both APG and CVO airports?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid = T2.Airline WHERE T2.SourceAirport = "APG" INTERSECT SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2...
#      pred_sql: SELECT T1.Airline FROM airlines AS T1 JOIN flights AS T2 ON T1.uid = T2.Airline WHERE T2.SourceAirport = "APG" INTERSECT SELECT T1.Airline FROM airlines AS T1 JOIN flights AS T2...
# [39/50] db_id=voter_1 question=What is the area code in which the most voters voted?
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT T1.area_code FROM area_code_state AS T1 JOIN votes AS T2 ON T1.state = T2.state GROUP BY T1.area_code ORDER BY count(*) DESC LIMIT 1
#      pred_sql: SELECT state FROM VOTES GROUP BY state ORDER BY count(*) DESC LIMIT 1;
# [40/50] db_id=wta_1 question=What is the best rank of losers across all matches?
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT min(loser_rank) FROM matches
#      pred_sql: SELECT max(loser_rank) FROM matches;
# [41/50] db_id=cre_Doc_Template_Mgt question=What are the ids for templates that are not used in any documents?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT template_id FROM Templates EXCEPT SELECT template_id FROM Documents
#      pred_sql: SELECT Template_ID FROM Templates EXCEPT SELECT Template_ID FROM Documents;
# [42/50] db_id=museum_visit question=What are the id and name of the museum visited most times?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT t2.Museum_ID , t1.name FROM museum AS t1 JOIN visit AS t2 ON t1.Museum_ID = t2.Museum_ID GROUP BY t2.Museum_ID ORDER BY count(*) DESC LIMIT 1
#      pred_sql: SELECT T1.museum_id , T1.name FROM museum AS T1 JOIN visit AS T2 ON T1.museum_id = T2.museum_id GROUP BY T1.museum_id ORDER BY count(*) DESC LIMIT 1;
# [43/50] db_id=orchestra question=How many different nationalities do conductors have?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT count(DISTINCT Nationality) FROM conductor
#      pred_sql: SELECT count(DISTINCT Nationality) FROM conductor;
# [44/50] db_id=concert_singer question=What is the name and country of origin of every singer who has a song with the word 'Hey' in its title?
#   -> FAIL: predicted SQL execution error (no such column: T2.Name)
#      gold_sql: SELECT name , country FROM singer WHERE song_name LIKE '%Hey%'
#      pred_sql: SELECT T2.Name , T2.Country FROM singer AS T1 JOIN concert AS T2 ON T1.Singer_ID = T2.Singer_ID WHERE T1.Song_Name LIKE '%Hey%';
# [45/50] db_id=cre_Doc_Template_Mgt question=What are the ids, version numbers, and type codes for each template?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT template_id , version_number , template_type_code FROM Templates
#      pred_sql: SELECT Template_ID , Version_Number , Template_Type_Code FROM Templates;
# [46/50] db_id=car_1 question=What is the model of the car with the smallest amount of horsepower?
#   -> FAIL | strict=FAIL | match=none | partial=0.00
#      gold_sql: SELECT T1.Model FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId = T2.Id ORDER BY T2.horsepower ASC LIMIT 1;
#      pred_sql: SELECT T1.Model FROM model_list AS T1 JOIN cars_data AS T2 ON T1.ModelId = T2.Id ORDER BY T2.Horsepower LIMIT 1;
# [47/50] db_id=car_1 question=What is the horsepower of the car with the greatest accelerate?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT T1.horsepower FROM CARS_DATA AS T1 ORDER BY T1.accelerate DESC LIMIT 1;
#      pred_sql: SELECT Horsepower FROM cars_data ORDER BY Accelerate DESC LIMIT 1;
# [48/50] db_id=dog_kennels question=What is the description of the treatment type that costs the least money in total?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT T1.treatment_type_description FROM Treatment_types AS T1 JOIN Treatments AS T2 ON T1.treatment_type_code = T2.treatment_type_code GROUP BY T1.treatment_type_code ORDER BY...
#      pred_sql: SELECT T3.treatment_type_description FROM treatments AS T1 JOIN treatment_types AS T3 ON T1.treatment_type_code = T3.treatment_type_code GROUP BY T1.treatment_type_code ORDER BY...
# [49/50] db_id=poker_player question=List the names of people that are not poker players.
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT Name FROM people WHERE People_ID NOT IN (SELECT People_ID FROM poker_player)
#      pred_sql: SELECT name FROM people WHERE people_id NOT IN (SELECT people_id FROM poker_player);
# [50/50] db_id=orchestra question=What are the record companies that are used by both orchestras founded before 2003 and those founded after 2003?
#   -> PASS | strict=PASS | match=exact | partial=1.00
#      gold_sql: SELECT Record_Company FROM orchestra WHERE Year_of_Founded < 2003 INTERSECT SELECT Record_Company FROM orchestra WHERE Year_of_Founded > 2003
#      pred_sql: SELECT T1.Record_Company FROM orchestra AS T1 JOIN conductor AS T2 ON T1.Conductor_ID = T2.Conductor_ID WHERE T1.Year_of_Founded < 2003 INTERSECT SELECT T1.Record_Company FROM o...
# Spider adapter on spider execution accuracy (relaxed): 0.7
# Spider adapter on spider execution accuracy (strict): 0.7
# Spider eval debug summary: {'total': 50, 'passed': 35, 'failed': 15, 'errors': 0, 'pred_exec_errors': 4}
# Showing first 12 non-pass examples
# --------------------------------------------------------------------------------
# [1] db_id=dog_kennels outcome=FAIL strict=FAIL
# Q: Find the owner id and zip code of the owner who spent the most money in total for his or her dogs.
# Match type: none | Partial: 0.0
# Gold: SELECT T1.owner_id , T1.zip_code FROM Owners AS T1 JOIN Dogs AS T2 ON T1.owner_id = T2.owner_id JOIN Treatments AS T3 ON T2.dog_id = T3.dog_id GROUP BY T1.owner_id ORDER BY sum(T3.cost_of_treatment) DESC LIMIT 1
# Pred: SELECT T1.owner_id , T1.zip_code FROM owners AS T1 JOIN treatments AS T2 ON T1.owner_id = T2.dog_id GROUP BY T1.owner_id ORDER BY sum(T2.cost_of_treatment) DESC LIMIT 1;
# --------------------------------------------------------------------------------
# [2] db_id=battle_death outcome=FAIL strict=FAIL
# Q: What is the ship id and name that caused most total injuries?
# Match type: none | Partial: 0.0
# Gold: SELECT T2.id , T2.name FROM death AS T1 JOIN ship AS t2 ON T1.caused_by_ship_id = T2.id GROUP BY T2.id ORDER BY count(*) DESC LIMIT 1
# Pred: SELECT T1.id , T1.name FROM ship AS T1 JOIN death AS T2 ON T1.id = T2.caused_by_ship_id GROUP BY T1.id ORDER BY sum(T2.injured) DESC LIMIT 1;
# --------------------------------------------------------------------------------
# [3] db_id=world_1 outcome=FAIL strict=FAIL
# Q: Which language is the most popular on the Asian continent?
# Match type: none | Partial: 0.0
# Gold: SELECT T2.Language FROM country AS T1 JOIN countrylanguage AS T2 ON T1.Code = T2.CountryCode WHERE T1.Continent = "Asia" GROUP BY T2.Language ORDER BY COUNT (*) DESC LIMIT 1
# Pred: SELECT T2.Language FROM country AS T1 JOIN countrylanguage AS T2 ON T1.Code = T2.CountryCode WHERE T1.Continent = 'Asia' ORDER BY T2.Percentage DESC LIMIT 1;
# --------------------------------------------------------------------------------
# [4] db_id=cre_Doc_Template_Mgt outcome=FAIL strict=FAIL
# Q: Return the id of the document with the fewest paragraphs.
# Match type: none | Partial: 0.0
# Gold: SELECT document_id FROM Paragraphs GROUP BY document_id ORDER BY count(*) ASC LIMIT 1
# Pred: SELECT document_id FROM documents GROUP BY document_id ORDER BY count(*) ASC LIMIT 1;
# --------------------------------------------------------------------------------
# [5] db_id=car_1 outcome=FAIL strict=FAIL
# Q: What are all the makers and models?
# Match type: none | Partial: 0.0
# Gold: SELECT Maker , Model FROM MODEL_LIST;
# Pred: SELECT DISTINCT T1.Maker , T1.Model FROM model_list AS T1 JOIN car_makers AS T2 ON T1.Maker = T2.Id;
# --------------------------------------------------------------------------------
# [6] db_id=dog_kennels outcome=FAIL strict=FAIL
# Q: Find the average age of the dogs who went through treatments.
# Match type: none | Partial: 0.0
# Gold: SELECT avg(age) FROM Dogs WHERE dog_id IN ( SELECT dog_id FROM Treatments )
# Pred: SELECT avg(T1.age) FROM Dogs AS T1 JOIN Treatments AS T2 ON T1.dog_id = T2.dog_id;
# --------------------------------------------------------------------------------
# [7] db_id=world_1 outcome=FAIL strict=FAIL
# Q: Count the number of countries for which Spanish is the predominantly spoken language.
# Error: no such column: Language
# Match type: none | Partial: 0.0
# Gold: SELECT count(*) , max(Percentage) FROM countrylanguage WHERE LANGUAGE = "Spanish" GROUP BY CountryCode
# Pred: SELECT count(*) FROM country WHERE Language = 'Spanish';
# --------------------------------------------------------------------------------
# [8] db_id=car_1 outcome=FAIL strict=FAIL
# Q: What is the name of each continent and how many car makers are there in each one?
# Match type: none | Partial: 0.0
# Gold: SELECT T1.Continent , count(*) FROM CONTINENTS AS T1 JOIN COUNTRIES AS T2 ON T1.ContId = T2.continent JOIN car_makers AS T3 ON T2.CountryId = T3.Country GROUP BY T1.Continent;
# Pred: SELECT T1.continent , count(*) FROM countries AS T1 JOIN car_makers AS T2 ON T1.countryid = T2.country GROUP BY T1.continent;
# --------------------------------------------------------------------------------
# [9] db_id=student_transcripts_tracking outcome=FAIL strict=FAIL
# Q: What is the zip code for Port Chelsea?
# Match type: none | Partial: 0.0
# Gold: SELECT zip_postcode FROM Addresses WHERE city = 'Port Chelsea'
# Pred: SELECT T1.zip_postcode FROM addresses AS T1 JOIN students AS T2 ON T1.address_id = T2.permanent_address_id WHERE T2.first_name = "Port" AND T2.last_name = "Chelsea";
# --------------------------------------------------------------------------------
# [10] db_id=car_1 outcome=FAIL strict=FAIL
# Q: Which distinctive models are produced by maker with the full name General Motors or weighing more than 3500?
# Error: no such column: T1.Weight
# Match type: none | Partial: 0.0
# Gold: SELECT DISTINCT T2.Model FROM CAR_NAMES AS T1 JOIN MODEL_LIST AS T2 ON T1.Model = T2.Model JOIN CAR_MAKERS AS T3 ON T2.Maker = T3.Id JOIN CARS_DATA AS T4 ON T1.MakeId = T4.Id WHERE T3.FullName = 'General Motors' OR T4.weight > 3500;
# Pred: SELECT DISTINCT T1.Model FROM model_list AS T1 JOIN car_makers AS T2 ON T1.Maker = T2.Id WHERE T2.FullName = "General Motors" OR T1.Weight > 3500;
# --------------------------------------------------------------------------------
# [11] db_id=world_1 outcome=FAIL strict=FAIL
# Q: What are the regions that use English or Dutch?
# Error: no such column: language
# Match type: none | Partial: 0.0
# Gold: SELECT DISTINCT T1.Region FROM country AS T1 JOIN countrylanguage AS T2 ON T1.Code = T2.CountryCode WHERE T2.Language = "English" OR T2.Language = "Dutch"
# Pred: SELECT DISTINCT region FROM country WHERE language = 'English' OR language = 'Dutch';
# --------------------------------------------------------------------------------
# [12] db_id=voter_1 outcome=FAIL strict=FAIL
# Q: What is the area code in which the most voters voted?
# Match type: none | Partial: 0.0
# Gold: SELECT T1.area_code FROM area_code_state AS T1 JOIN votes AS T2 ON T1.state = T2.state GROUP BY T1.area_code ORDER BY count(*) DESC LIMIT 1
# Pred: SELECT state FROM VOTES GROUP BY state ORDER BY count(*) DESC LIMIT 1;

# %% [markdown]
# ## 9) Compare Baseline vs Spider Adapter

# %%
summary = pd.DataFrame([
    {
        "Run": "Baseline (Base Model)",
        "Spider Exec (Relaxed)": baseline_spider_report.get("execution_accuracy"),
        "Spider Exec (Strict)": baseline_spider_report.get("strict_execution_accuracy"),
        "Spider Partial-Credit": baseline_spider_report.get("partial_credit_accuracy"),
        "Spider Eval N": baseline_spider_report.get("total"),
    },
    {
        "Run": "Spider Adapter",
        "Spider Exec (Relaxed)": spider_ft_spider_report.get("execution_accuracy"),
        "Spider Exec (Strict)": spider_ft_spider_report.get("strict_execution_accuracy"),
        "Spider Partial-Credit": spider_ft_spider_report.get("partial_credit_accuracy"),
        "Spider Eval N": spider_ft_spider_report.get("total"),
    },
])

display(summary)
print("Spider adapter path:", spider_adapter_dir)
print("Spider DB root:", SPIDER_DB_ROOT)
# Out:
#                      Run  Spider Exec (Relaxed)  Spider Exec (Strict)  \
# 0  Baseline (Base Model)                   0.58                  0.58
# 1         Spider Adapter                   0.70                  0.70
#
#    Spider Partial-Credit  Spider Eval N
# 0                   0.58             50
# 1                   0.70             50
# Spider adapter path: /content/outputs/dual_adapters/spider_adapter/final_adapter
# Spider DB root: /content/spider_data/database
